# %%
import numpy as np
from scipy.sparse import random as sparse_random
from scipy.sparse.linalg import eigsh
import matplotlib.pyplot as plt

def generate_sparse_matrix(size, density):
    # Step 1: Print information about matrix generation
    print(f"Generating sparse matrix with size {size} and density {density:.2%}")
    
    rvs = np.random.randn  
    upper = sparse_random(size, size, density=density/2, data_rvs=rvs, format='coo')
    matrix_s = upper + upper.T
    
    # Print matrix details after generation
    print(f"Matrix generated with shape {matrix_s.shape} and nnz (non-zero elements) {matrix_s.nnz}")
    
    return matrix_s.tocsr()  

def lanczos_algorithm(matrix_s, initial_vector, expected_eigenvalue, tol=1e-6, max_iter=10000):
    m = matrix_s.shape[0]
    print(f"Starting Lanczos algorithm with matrix size {m}, expected eigenvalue {expected_eigenvalue:.6f}, and tolerance {tol}")
    
    krylov_vectors = np.zeros((m, max_iter + 1))
    tridiag_matrix = np.zeros((max_iter + 1, max_iter))
    w = initial_vector / np.linalg.norm(initial_vector)
    krylov_vectors[:, 0] = w
    print(f"Initial vector normalized (first 10 elements): {w[:10]}")
    
    for k in range(max_iter):
        print(f"\n--- Iteration {k+1} ---")
        v = matrix_s.dot(krylov_vectors[:, k])
        tridiag_matrix[k, k] = np.dot(krylov_vectors[:, k].conj(), v)
        print(f"Tridiagonal matrix diagonal element at [{k}, {k}] = {tridiag_matrix[k, k]:.6f}")
        v = v - tridiag_matrix[k, k] * krylov_vectors[:, k]
        if k > 0:
            v = v - tridiag_matrix[k, k-1] * krylov_vectors[:, k-1]
        tridiag_matrix[k + 1, k] = np.linalg.norm(v)
        print(f"Tridiagonal matrix off-diagonal element at [{k+1}, {k}] = {tridiag_matrix[k + 1, k]:.6f}")

        if tridiag_matrix[k + 1, k] > tol:
            krylov_vectors[:, k + 1] = v / tridiag_matrix[k + 1, k]
        else:
            print(f"Convergence reached at iteration {k+1}, stopping Lanczos.")
            break
        
        eigenvalues = np.linalg.eigvalsh(tridiag_matrix[:k + 1, :k + 1])
        estimated_eigenvalue = eigenvalues[0]
        print(f"Estimated eigenvalue: {estimated_eigenvalue:.6f}")

        if abs(estimated_eigenvalue - expected_eigenvalue) < tol:
            print(f"Converged after {k+1} iterations with eigenvalue {estimated_eigenvalue:.6f}")
            return k + 1  
    
    print(f"Max iterations reached without convergence. Returning {max_iter}.")
    return max_iter

def evaluate_average_iterations(size, density_levels, initial_vector, num_trials=2, tol=1e-6, max_iter=10000):
    avg_iterations_per_density = []
    
    for density in density_levels:
        print(f"\n--- Evaluating Density Level: {density:.2%} ---")
        total_iterations = 0
        
        for trial in range(num_trials):
            print(f"\nTrial {trial+1} for density level {density:.2%}")
            matrix_s = generate_sparse_matrix(size, density)
            exact_eigenvalue, _ = eigsh(matrix_s, k=1, which='SA', tol=tol)
            exact_eigenvalue = exact_eigenvalue[0]
            print(f"Exact smallest eigenvalue from eigsh: {exact_eigenvalue:.6f}")
            
            num_iterations = lanczos_algorithm(matrix_s, initial_vector, exact_eigenvalue, tol, max_iter)
            print(f"Number of iterations for trial {trial+1}: {num_iterations}")
            total_iterations += num_iterations
        
        avg_iterations = total_iterations / num_trials
        avg_iterations_per_density.append(avg_iterations)
        print(f"Density: {density:.2%}, Average Lanczos Basis Size: {avg_iterations}")
    
    return avg_iterations_per_density

# Parameters
size = 10000
density_levels = [0.01, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5, 0.55, 0.6, 0.65, 0.7, 0.75, 0.8, 0.85, 0.9, 0.95, 1.0]
initial_vector = np.random.rand(size)  # random initial vector

# Evaluate the basis size for different sparsity levels
average_basis_sizes = evaluate_average_iterations(size, density_levels, initial_vector, num_trials=2)

# Plot the results
plt.figure(figsize=(10, 6))
plt.plot(density_levels, average_basis_sizes, marker='o', linestyle='-', color='b')
plt.xlabel('Density Level (%)')
plt.ylabel('Average Lanczos Basis Size')
plt.title('Density vs Average Lanczos Basis Size')
plt.grid(True)
plt.show()
# Out:
# --- Evaluating Density Level: 1.00% ---
#
# Trial 1 for density level 1.00%
# Generating sparse matrix with size 10000 and density 1.00%
# Matrix generated with shape (10000, 10000) and nnz (non-zero elements) 997400
# Exact smallest eigenvalue from eigsh: -20.249709
# Starting Lanczos algorithm with matrix size 10000, expected eigenvalue -20.249709, and tolerance 1e-06
# Initial vector normalized (first 10 elements): [0.00582943 0.00818132 0.00637978 0.00738742 0.00391784 0.01118027
#  0.0078716  0.00101017 0.00508118 0.01087281]
#
# --- Iteration 1 ---
# Tridiagonal matrix diagonal element at [0, 0] = 0.256945
# Tridiagonal matrix off-diagonal element at [1, 0] = 10.019065
# Estimated eigenvalue: 0.256945
#
# --- Iteration 2 ---
# Tridiagonal matrix diagonal element at [1, 1] = 0.015693
# Tridiagonal matrix off-diagonal element at [2, 1] = 10.078891
# Estimated eigenvalue: -9.883472
#
# --- Iteration 3 ---
# Tridiagonal matrix diagonal element at [2, 2] = 0.073070
# Tridiagonal matrix off-diagonal element at [3, 2] = 10.062782
# Estimated eigenvalue: -14.121876
#
# --- Iteration 4 ---
# Tridiagonal matrix diagonal element at [3, 3] = -0.183986
# Tridiagonal matrix off-diagonal element at [4, 3] = 10.211101
# Estimated eigenvalue: -16.233193
#
# --- Iteration 5 ---
# Tridiagonal matrix diagonal element at [4, 4] = -0.038992
# Tridiagonal matrix off-diagonal element at [5, 4] = 10.132543
# Estimated eigenvalue: -17.472170
#
# --- Iteration 6 ---
# Tridiagonal matrix diagonal element at [5, 5] = -0.329793
# Tridiagonal matrix off-diagonal element at [6, 5] = 10.086217
# Estimated eigenvalue: -18.253428
#
# --- Iteration 7 ---
# Tridiagonal matrix diagonal element at [6, 6] = -0.165367
# Tridiagonal matrix off-diagonal element at [7, 6] = 10.246637
# Estimated eigenvalue: -18.768923
#
# --- Iteration 8 ---
# Tridiagonal matrix diagonal element at [7, 7] = -0.208759
# Tridiagonal matrix off-diagonal element at [8, 7] = 10.120360
# Estimated eigenvalue: -19.136997
#
# --- Iteration 9 ---
# Tridiagonal matrix diagonal element at [8, 8] = 0.184563
# Tridiagonal matrix off-diagonal element at [9, 8] = 10.177959
# Estimated eigenvalue: -19.394948
#
# --- Iteration 10 ---
# Tridiagonal matrix diagonal element at [9, 9] = 0.121256
# Tridiagonal matrix off-diagonal element at [10, 9] = 10.150275
# Estimated eigenvalue: -19.574642
#
# --- Iteration 11 ---
# Tridiagonal matrix diagonal element at [10, 10] = -0.058437
# Tridiagonal matrix off-diagonal element at [11, 10] = 10.116387
# Estimated eigenvalue: -19.703163
#
# --- Iteration 12 ---
# Tridiagonal matrix diagonal element at [11, 11] = 0.341404
# Tridiagonal matrix off-diagonal element at [12, 11] = 10.215941
# Estimated eigenvalue: -19.795109
#
# --- Iteration 13 ---
# Tridiagonal matrix diagonal element at [12, 12] = 0.140936
# Tridiagonal matrix off-diagonal element at [13, 12] = 10.144168
# Estimated eigenvalue: -19.862690
#
# --- Iteration 14 ---
# Tridiagonal matrix diagonal element at [13, 13] = 0.226434
# Tridiagonal matrix off-diagonal element at [14, 13] = 10.107573
# Estimated eigenvalue: -19.912974
#
# --- Iteration 15 ---
# Tridiagonal matrix diagonal element at [14, 14] = 0.161450
# Tridiagonal matrix off-diagonal element at [15, 14] = 10.234909
# Estimated eigenvalue: -19.950400
#
# --- Iteration 16 ---
# Tridiagonal matrix diagonal element at [15, 15] = -0.171004
# Tridiagonal matrix off-diagonal element at [16, 15] = 10.054892
# Estimated eigenvalue: -19.980706
#
# --- Iteration 17 ---
# Tridiagonal matrix diagonal element at [16, 16] = 0.148985
# Tridiagonal matrix off-diagonal element at [17, 16] = 10.142474
# Estimated eigenvalue: -20.005329
#
# --- Iteration 18 ---
# Tridiagonal matrix diagonal element at [17, 17] = 0.045003
# Tridiagonal matrix off-diagonal element at [18, 17] = 10.126431
# Estimated eigenvalue: -20.025629
#
# --- Iteration 19 ---
# Tridiagonal matrix diagonal element at [18, 18] = -0.297147
# Tridiagonal matrix off-diagonal element at [19, 18] = 10.300457
# Estimated eigenvalue: -20.043182
#
# --- Iteration 20 ---
# Tridiagonal matrix diagonal element at [19, 19] = -0.019754
# Tridiagonal matrix off-diagonal element at [20, 19] = 10.222673
# Estimated eigenvalue: -20.060131
#
# --- Iteration 21 ---
# Tridiagonal matrix diagonal element at [20, 20] = 0.079835
# Tridiagonal matrix off-diagonal element at [21, 20] = 10.147617
# Estimated eigenvalue: -20.076980
#
# --- Iteration 22 ---
# Tridiagonal matrix diagonal element at [21, 21] = 0.009515
# Tridiagonal matrix off-diagonal element at [22, 21] = 10.205779
# Estimated eigenvalue: -20.093520
#
# --- Iteration 23 ---
# Tridiagonal matrix diagonal element at [22, 22] = 0.151302
# Tridiagonal matrix off-diagonal element at [23, 22] = 10.035669
# Estimated eigenvalue: -20.109690
#
# --- Iteration 24 ---
# Tridiagonal matrix diagonal element at [23, 23] = 0.017899
# Tridiagonal matrix off-diagonal element at [24, 23] = 10.103502
# Estimated eigenvalue: -20.124366
#
# --- Iteration 25 ---
# Tridiagonal matrix diagonal element at [24, 24] = -0.108328
# Tridiagonal matrix off-diagonal element at [25, 24] = 10.175174
# Estimated eigenvalue: -20.137468
#
# --- Iteration 26 ---
# Tridiagonal matrix diagonal element at [25, 25] = 0.076123
# Tridiagonal matrix off-diagonal element at [26, 25] = 9.818619
# Estimated eigenvalue: -20.149279
#
# --- Iteration 27 ---
# Tridiagonal matrix diagonal element at [26, 26] = -0.076003
# Tridiagonal matrix off-diagonal element at [27, 26] = 10.083293
# Estimated eigenvalue: -20.158695
#
# --- Iteration 28 ---
# Tridiagonal matrix diagonal element at [27, 27] = -0.117663
# Tridiagonal matrix off-diagonal element at [28, 27] = 10.279071
# Estimated eigenvalue: -20.166336
#
# --- Iteration 29 ---
# Tridiagonal matrix diagonal element at [28, 28] = -0.155995
# Tridiagonal matrix off-diagonal element at [29, 28] = 10.116116
# Estimated eigenvalue: -20.173173
#
# --- Iteration 30 ---
# Tridiagonal matrix diagonal element at [29, 29] = -0.071000
# Tridiagonal matrix off-diagonal element at [30, 29] = 10.210978
# Estimated eigenvalue: -20.179416
#
# --- Iteration 31 ---
# Tridiagonal matrix diagonal element at [30, 30] = 0.137923
# Tridiagonal matrix off-diagonal element at [31, 30] = 10.175664
# Estimated eigenvalue: -20.185266
#
# --- Iteration 32 ---
# Tridiagonal matrix diagonal element at [31, 31] = 0.016238
# Tridiagonal matrix off-diagonal element at [32, 31] = 10.056438
# Estimated eigenvalue: -20.190753
#
# --- Iteration 33 ---
# Tridiagonal matrix diagonal element at [32, 32] = 0.089219
# Tridiagonal matrix off-diagonal element at [33, 32] = 10.104915
# Estimated eigenvalue: -20.195694
#
# --- Iteration 34 ---
# Tridiagonal matrix diagonal element at [33, 33] = 0.077531
# Tridiagonal matrix off-diagonal element at [34, 33] = 10.158923
# Estimated eigenvalue: -20.200040
#
# --- Iteration 35 ---
# Tridiagonal matrix diagonal element at [34, 34] = -0.009428
# Tridiagonal matrix off-diagonal element at [35, 34] = 10.116683
# Estimated eigenvalue: -20.203897
#
# --- Iteration 36 ---
# Tridiagonal matrix diagonal element at [35, 35] = -0.175854
# Tridiagonal matrix off-diagonal element at [36, 35] = 10.267136
# Estimated eigenvalue: -20.207378
#
# --- Iteration 37 ---
# Tridiagonal matrix diagonal element at [36, 36] = 0.154548
# Tridiagonal matrix off-diagonal element at [37, 36] = 10.084648
# Estimated eigenvalue: -20.210704
#
# --- Iteration 38 ---
# Tridiagonal matrix diagonal element at [37, 37] = -0.209597
# Tridiagonal matrix off-diagonal element at [38, 37] = 10.111916
# Estimated eigenvalue: -20.213838
#
# --- Iteration 39 ---
# Tridiagonal matrix diagonal element at [38, 38] = 0.142300
# Tridiagonal matrix off-diagonal element at [39, 38] = 10.115206
# Estimated eigenvalue: -20.216784
#
# --- Iteration 40 ---
# Tridiagonal matrix diagonal element at [39, 39] = -0.028218
# Tridiagonal matrix off-diagonal element at [40, 39] = 10.160216
# Estimated eigenvalue: -20.219504
#
# --- Iteration 41 ---
# Tridiagonal matrix diagonal element at [40, 40] = -0.111677
# Tridiagonal matrix off-diagonal element at [41, 40] = 10.065358
# Estimated eigenvalue: -20.222077
#
# --- Iteration 42 ---
# Tridiagonal matrix diagonal element at [41, 41] = -0.085448
# Tridiagonal matrix off-diagonal element at [42, 41] = 10.041040
# Estimated eigenvalue: -20.224490
#
# --- Iteration 43 ---
# Tridiagonal matrix diagonal element at [42, 42] = 0.168280
# Tridiagonal matrix off-diagonal element at [43, 42] = 10.120863
# Estimated eigenvalue: -20.226657
#
# --- Iteration 44 ---
# Tridiagonal matrix diagonal element at [43, 43] = -0.140041
# Tridiagonal matrix off-diagonal element at [44, 43] = 10.109559
# Estimated eigenvalue: -20.228596
#
# --- Iteration 45 ---
# Tridiagonal matrix diagonal element at [44, 44] = 0.103836
# Tridiagonal matrix off-diagonal element at [45, 44] = 10.218422
# Estimated eigenvalue: -20.230330
#
# --- Iteration 46 ---
# Tridiagonal matrix diagonal element at [45, 45] = 0.176999
# Tridiagonal matrix off-diagonal element at [46, 45] = 10.129407
# Estimated eigenvalue: -20.231897
#
# --- Iteration 47 ---
# Tridiagonal matrix diagonal element at [46, 46] = -0.213737
# Tridiagonal matrix off-diagonal element at [47, 46] = 10.213066
# Estimated eigenvalue: -20.233324
#
# --- Iteration 48 ---
# Tridiagonal matrix diagonal element at [47, 47] = 0.093969
# Tridiagonal matrix off-diagonal element at [48, 47] = 10.180613
# Estimated eigenvalue: -20.234684
#
# --- Iteration 49 ---
# Tridiagonal matrix diagonal element at [48, 48] = 0.009809
# Tridiagonal matrix off-diagonal element at [49, 48] = 10.099130
# Estimated eigenvalue: -20.235992
#
# --- Iteration 50 ---
# Tridiagonal matrix diagonal element at [49, 49] = -0.123941
# Tridiagonal matrix off-diagonal element at [50, 49] = 10.181735
# Estimated eigenvalue: -20.237249
#
# --- Iteration 51 ---
# Tridiagonal matrix diagonal element at [50, 50] = -0.187548
# Tridiagonal matrix off-diagonal element at [51, 50] = 10.050932
# Estimated eigenvalue: -20.238516
#
# --- Iteration 52 ---
# Tridiagonal matrix diagonal element at [51, 51] = 0.044174
# Tridiagonal matrix off-diagonal element at [52, 51] = 9.975973
# Estimated eigenvalue: -20.239770
#
# --- Iteration 53 ---
# Tridiagonal matrix diagonal element at [52, 52] = -0.201523
# Tridiagonal matrix off-diagonal element at [53, 52] = 10.142537
# Estimated eigenvalue: -20.240951
#
# --- Iteration 54 ---
# Tridiagonal matrix diagonal element at [53, 53] = 0.237249
# Tridiagonal matrix off-diagonal element at [54, 53] = 10.131486
# Estimated eigenvalue: -20.242064
#
# --- Iteration 55 ---
# Tridiagonal matrix diagonal element at [54, 54] = -0.104543
# Tridiagonal matrix off-diagonal element at [55, 54] = 10.118387
# Estimated eigenvalue: -20.243099
#
# --- Iteration 56 ---
# Tridiagonal matrix diagonal element at [55, 55] = 0.148782
# Tridiagonal matrix off-diagonal element at [56, 55] = 10.102016
# Estimated eigenvalue: -20.244052
#
# --- Iteration 57 ---
# Tridiagonal matrix diagonal element at [56, 56] = 0.186622
# Tridiagonal matrix off-diagonal element at [57, 56] = 10.192968
# Estimated eigenvalue: -20.244894
#
# --- Iteration 58 ---
# Tridiagonal matrix diagonal element at [57, 57] = 0.311212
# Tridiagonal matrix off-diagonal element at [58, 57] = 10.092432
# Estimated eigenvalue: -20.245626
#
# --- Iteration 59 ---
# Tridiagonal matrix diagonal element at [58, 58] = -0.063176
# Tridiagonal matrix off-diagonal element at [59, 58] = 10.189506
# Estimated eigenvalue: -20.246245
#
# --- Iteration 60 ---
# Tridiagonal matrix diagonal element at [59, 59] = -0.009494
# Tridiagonal matrix off-diagonal element at [60, 59] = 10.065941
# Estimated eigenvalue: -20.246790
#
# --- Iteration 61 ---
# Tridiagonal matrix diagonal element at [60, 60] = -0.081854
# Tridiagonal matrix off-diagonal element at [61, 60] = 10.080411
# Estimated eigenvalue: -20.247265
#
# --- Iteration 62 ---
# Tridiagonal matrix diagonal element at [61, 61] = -0.036569
# Tridiagonal matrix off-diagonal element at [62, 61] = 10.021833
# Estimated eigenvalue: -20.247682
#
# --- Iteration 63 ---
# Tridiagonal matrix diagonal element at [62, 62] = 0.182979
# Tridiagonal matrix off-diagonal element at [63, 62] = 10.028908
# Estimated eigenvalue: -20.248030
#
# --- Iteration 64 ---
# Tridiagonal matrix diagonal element at [63, 63] = 0.105868
# Tridiagonal matrix off-diagonal element at [64, 63] = 9.990509
# Estimated eigenvalue: -20.248308
#
# --- Iteration 65 ---
# Tridiagonal matrix diagonal element at [64, 64] = 0.145796
# Tridiagonal matrix off-diagonal element at [65, 64] = 10.126205
# Estimated eigenvalue: -20.248520
#
# --- Iteration 66 ---
# Tridiagonal matrix diagonal element at [65, 65] = 0.112789
# Tridiagonal matrix off-diagonal element at [66, 65] = 10.079420
# Estimated eigenvalue: -20.248682
#
# --- Iteration 67 ---
# Tridiagonal matrix diagonal element at [66, 66] = -0.322934
# Tridiagonal matrix off-diagonal element at [67, 66] = 10.079599
# Estimated eigenvalue: -20.248812
#
# --- Iteration 68 ---
# Tridiagonal matrix diagonal element at [67, 67] = 0.363190
# Tridiagonal matrix off-diagonal element at [68, 67] = 10.221264
# Estimated eigenvalue: -20.248915
#
# --- Iteration 69 ---
# Tridiagonal matrix diagonal element at [68, 68] = -0.238062
# Tridiagonal matrix off-diagonal element at [69, 68] = 10.207415
# Estimated eigenvalue: -20.249001
#
# --- Iteration 70 ---
# Tridiagonal matrix diagonal element at [69, 69] = 0.189668
# Tridiagonal matrix off-diagonal element at [70, 69] = 9.953103
# Estimated eigenvalue: -20.249077
#
# --- Iteration 71 ---
# Tridiagonal matrix diagonal element at [70, 70] = -0.105213
# Tridiagonal matrix off-diagonal element at [71, 70] = 10.234237
# Estimated eigenvalue: -20.249140
#
# --- Iteration 72 ---
# Tridiagonal matrix diagonal element at [71, 71] = 0.025164
# Tridiagonal matrix off-diagonal element at [72, 71] = 10.061414
# Estimated eigenvalue: -20.249195
#
# --- Iteration 73 ---
# Tridiagonal matrix diagonal element at [72, 72] = 0.048368
# Tridiagonal matrix off-diagonal element at [73, 72] = 10.058802
# Estimated eigenvalue: -20.249242
#
# --- Iteration 74 ---
# Tridiagonal matrix diagonal element at [73, 73] = -0.008954
# Tridiagonal matrix off-diagonal element at [74, 73] = 10.112183
# Estimated eigenvalue: -20.249282
#
# --- Iteration 75 ---
# Tridiagonal matrix diagonal element at [74, 74] = 0.026395
# Tridiagonal matrix off-diagonal element at [75, 74] = 10.163186
# Estimated eigenvalue: -20.249316
#
# --- Iteration 76 ---
# Tridiagonal matrix diagonal element at [75, 75] = -0.065580
# Tridiagonal matrix off-diagonal element at [76, 75] = 10.188351
# Estimated eigenvalue: -20.249346
#
# --- Iteration 77 ---
# Tridiagonal matrix diagonal element at [76, 76] = -0.147123
# Tridiagonal matrix off-diagonal element at [77, 76] = 10.138359
# Estimated eigenvalue: -20.249373
#
# --- Iteration 78 ---
# Tridiagonal matrix diagonal element at [77, 77] = 0.032158
# Tridiagonal matrix off-diagonal element at [78, 77] = 10.217412
# Estimated eigenvalue: -20.249399
#
# --- Iteration 79 ---
# Tridiagonal matrix diagonal element at [78, 78] = 0.120437
# Tridiagonal matrix off-diagonal element at [79, 78] = 10.062756
# Estimated eigenvalue: -20.249424
#
# --- Iteration 80 ---
# Tridiagonal matrix diagonal element at [79, 79] = -0.006901
# Tridiagonal matrix off-diagonal element at [80, 79] = 10.146896
# Estimated eigenvalue: -20.249447
#
# --- Iteration 81 ---
# Tridiagonal matrix diagonal element at [80, 80] = 0.111559
# Tridiagonal matrix off-diagonal element at [81, 80] = 10.014621
# Estimated eigenvalue: -20.249469
#
# --- Iteration 82 ---
# Tridiagonal matrix diagonal element at [81, 81] = 0.063107
# Tridiagonal matrix off-diagonal element at [82, 81] = 10.101894
# Estimated eigenvalue: -20.249488
#
# --- Iteration 83 ---
# Tridiagonal matrix diagonal element at [82, 82] = -0.227885
# Tridiagonal matrix off-diagonal element at [83, 82] = 10.062910
# Estimated eigenvalue: -20.249505
#
# --- Iteration 84 ---
# Tridiagonal matrix diagonal element at [83, 83] = -0.221347
# Tridiagonal matrix off-diagonal element at [84, 83] = 10.121956
# Estimated eigenvalue: -20.249521
#
# --- Iteration 85 ---
# Tridiagonal matrix diagonal element at [84, 84] = 0.182272
# Tridiagonal matrix off-diagonal element at [85, 84] = 10.222228
# Estimated eigenvalue: -20.249535
#
# --- Iteration 86 ---
# Tridiagonal matrix diagonal element at [85, 85] = 0.039539
# Tridiagonal matrix off-diagonal element at [86, 85] = 10.158081
# Estimated eigenvalue: -20.249548
#
# --- Iteration 87 ---
# Tridiagonal matrix diagonal element at [86, 86] = 0.163211
# Tridiagonal matrix off-diagonal element at [87, 86] = 10.078995
# Estimated eigenvalue: -20.249561
#
# --- Iteration 88 ---
# Tridiagonal matrix diagonal element at [87, 87] = -0.083307
# Tridiagonal matrix off-diagonal element at [88, 87] = 10.221541
# Estimated eigenvalue: -20.249573
#
# --- Iteration 89 ---
# Tridiagonal matrix diagonal element at [88, 88] = 0.006167
# Tridiagonal matrix off-diagonal element at [89, 88] = 10.153823
# Estimated eigenvalue: -20.249584
#
# --- Iteration 90 ---
# Tridiagonal matrix diagonal element at [89, 89] = -0.182696
# Tridiagonal matrix off-diagonal element at [90, 89] = 9.993674
# Estimated eigenvalue: -20.249595
#
# --- Iteration 91 ---
# Tridiagonal matrix diagonal element at [90, 90] = 0.056058
# Tridiagonal matrix off-diagonal element at [91, 90] = 10.128848
# Estimated eigenvalue: -20.249605
#
# --- Iteration 92 ---
# Tridiagonal matrix diagonal element at [91, 91] = 0.010851
# Tridiagonal matrix off-diagonal element at [92, 91] = 10.040554
# Estimated eigenvalue: -20.249615
#
# --- Iteration 93 ---
# Tridiagonal matrix diagonal element at [92, 92] = -0.081612
# Tridiagonal matrix off-diagonal element at [93, 92] = 10.099503
# Estimated eigenvalue: -20.249624
#
# --- Iteration 94 ---
# Tridiagonal matrix diagonal element at [93, 93] = -0.005904
# Tridiagonal matrix off-diagonal element at [94, 93] = 10.087600
# Estimated eigenvalue: -20.249632
#
# --- Iteration 95 ---
# Tridiagonal matrix diagonal element at [94, 94] = -0.071188
# Tridiagonal matrix off-diagonal element at [95, 94] = 10.086680
# Estimated eigenvalue: -20.249640
#
# --- Iteration 96 ---
# Tridiagonal matrix diagonal element at [95, 95] = -0.195781
# Tridiagonal matrix off-diagonal element at [96, 95] = 10.137557
# Estimated eigenvalue: -20.249647
#
# --- Iteration 97 ---
# Tridiagonal matrix diagonal element at [96, 96] = 0.114382
# Tridiagonal matrix off-diagonal element at [97, 96] = 10.108004
# Estimated eigenvalue: -20.249654
#
# --- Iteration 98 ---
# Tridiagonal matrix diagonal element at [97, 97] = -0.222748
# Tridiagonal matrix off-diagonal element at [98, 97] = 9.988822
# Estimated eigenvalue: -20.249661
#
# --- Iteration 99 ---
# Tridiagonal matrix diagonal element at [98, 98] = -0.159633
# Tridiagonal matrix off-diagonal element at [99, 98] = 10.165278
# Estimated eigenvalue: -20.249667
#
# --- Iteration 100 ---
# Tridiagonal matrix diagonal element at [99, 99] = 0.058374
# Tridiagonal matrix off-diagonal element at [100, 99] = 10.100843
# Estimated eigenvalue: -20.249673
#
# --- Iteration 101 ---
# Tridiagonal matrix diagonal element at [100, 100] = -0.059457
# Tridiagonal matrix off-diagonal element at [101, 100] = 9.996506
# Estimated eigenvalue: -20.249679
#
# --- Iteration 102 ---
# Tridiagonal matrix diagonal element at [101, 101] = 0.170636
# Tridiagonal matrix off-diagonal element at [102, 101] = 10.029673
# Estimated eigenvalue: -20.249684
#
# --- Iteration 103 ---
# Tridiagonal matrix diagonal element at [102, 102] = 0.033965
# Tridiagonal matrix off-diagonal element at [103, 102] = 9.941357
# Estimated eigenvalue: -20.249688
#
# --- Iteration 104 ---
# Tridiagonal matrix diagonal element at [103, 103] = 0.023185
# Tridiagonal matrix off-diagonal element at [104, 103] = 10.009907
# Estimated eigenvalue: -20.249692
#
# --- Iteration 105 ---
# Tridiagonal matrix diagonal element at [104, 104] = 0.202518
# Tridiagonal matrix off-diagonal element at [105, 104] = 10.048340
# Estimated eigenvalue: -20.249695
#
# --- Iteration 106 ---
# Tridiagonal matrix diagonal element at [105, 105] = -0.170357
# Tridiagonal matrix off-diagonal element at [106, 105] = 10.087278
# Estimated eigenvalue: -20.249697
#
# --- Iteration 107 ---
# Tridiagonal matrix diagonal element at [106, 106] = 0.159246
# Tridiagonal matrix off-diagonal element at [107, 106] = 10.151073
# Estimated eigenvalue: -20.249699
#
# --- Iteration 108 ---
# Tridiagonal matrix diagonal element at [107, 107] = -0.023198
# Tridiagonal matrix off-diagonal element at [108, 107] = 10.028368
# Estimated eigenvalue: -20.249700
#
# --- Iteration 109 ---
# Tridiagonal matrix diagonal element at [108, 108] = -0.141788
# Tridiagonal matrix off-diagonal element at [109, 108] = 10.336490
# Estimated eigenvalue: -20.249701
#
# --- Iteration 110 ---
# Tridiagonal matrix diagonal element at [109, 109] = 0.010904
# Tridiagonal matrix off-diagonal element at [110, 109] = 10.123028
# Estimated eigenvalue: -20.249702
#
# --- Iteration 111 ---
# Tridiagonal matrix diagonal element at [110, 110] = -0.019754
# Tridiagonal matrix off-diagonal element at [111, 110] = 10.024610
# Estimated eigenvalue: -20.249703
#
# --- Iteration 112 ---
# Tridiagonal matrix diagonal element at [111, 111] = 0.161816
# Tridiagonal matrix off-diagonal element at [112, 111] = 10.252328
# Estimated eigenvalue: -20.249704
#
# --- Iteration 113 ---
# Tridiagonal matrix diagonal element at [112, 112] = -0.043480
# Tridiagonal matrix off-diagonal element at [113, 112] = 10.124296
# Estimated eigenvalue: -20.249704
#
# --- Iteration 114 ---
# Tridiagonal matrix diagonal element at [113, 113] = -0.030908
# Tridiagonal matrix off-diagonal element at [114, 113] = 10.060853
# Estimated eigenvalue: -20.249705
#
# --- Iteration 115 ---
# Tridiagonal matrix diagonal element at [114, 114] = 0.215418
# Tridiagonal matrix off-diagonal element at [115, 114] = 10.078755
# Estimated eigenvalue: -20.249706
#
# --- Iteration 116 ---
# Tridiagonal matrix diagonal element at [115, 115] = 0.010228
# Tridiagonal matrix off-diagonal element at [116, 115] = 10.179152
# Estimated eigenvalue: -20.249706
#
# --- Iteration 117 ---
# Tridiagonal matrix diagonal element at [116, 116] = -0.104712
# Tridiagonal matrix off-diagonal element at [117, 116] = 9.998642
# Estimated eigenvalue: -20.249707
#
# --- Iteration 118 ---
# Tridiagonal matrix diagonal element at [117, 117] = 0.200398
# Tridiagonal matrix off-diagonal element at [118, 117] = 10.037695
# Estimated eigenvalue: -20.249707
#
# --- Iteration 119 ---
# Tridiagonal matrix diagonal element at [118, 118] = -0.154805
# Tridiagonal matrix off-diagonal element at [119, 118] = 10.096074
# Estimated eigenvalue: -20.249707
#
# --- Iteration 120 ---
# Tridiagonal matrix diagonal element at [119, 119] = -0.161277
# Tridiagonal matrix off-diagonal element at [120, 119] = 10.146584
# Estimated eigenvalue: -20.249707
#
# --- Iteration 121 ---
# Tridiagonal matrix diagonal element at [120, 120] = 0.086911
# Tridiagonal matrix off-diagonal element at [121, 120] = 10.028852
# Estimated eigenvalue: -20.249708
#
# --- Iteration 122 ---
# Tridiagonal matrix diagonal element at [121, 121] = -0.049034
# Tridiagonal matrix off-diagonal element at [122, 121] = 10.187727
# Estimated eigenvalue: -20.249708
#
# --- Iteration 123 ---
# Tridiagonal matrix diagonal element at [122, 122] = 0.000271
# Tridiagonal matrix off-diagonal element at [123, 122] = 10.112684
# Estimated eigenvalue: -20.249708
# Converged after 123 iterations with eigenvalue -20.249708
# Number of iterations for trial 1: 123
#
# Trial 2 for density level 1.00%
# Generating sparse matrix with size 10000 and density 1.00%
# Matrix generated with shape (10000, 10000) and nnz (non-zero elements) 997623
# Exact smallest eigenvalue from eigsh: -20.234638
# Starting Lanczos algorithm with matrix size 10000, expected eigenvalue -20.234638, and tolerance 1e-06
# Initial vector normalized (first 10 elements): [0.00582943 0.00818132 0.00637978 0.00738742 0.00391784 0.01118027
#  0.0078716  0.00101017 0.00508118 0.01087281]
#
# --- Iteration 1 ---
# Tridiagonal matrix diagonal element at [0, 0] = 0.310451
# Tridiagonal matrix off-diagonal element at [1, 0] = 10.037535
# Estimated eigenvalue: 0.310451
#
# --- Iteration 2 ---
# Tridiagonal matrix diagonal element at [1, 1] = 0.097973
# Tridiagonal matrix off-diagonal element at [2, 1] = 10.081960
# Estimated eigenvalue: -9.833885
#
# --- Iteration 3 ---
# Tridiagonal matrix diagonal element at [2, 2] = -0.041503
# Tridiagonal matrix off-diagonal element at [3, 2] = 10.140072
# Estimated eigenvalue: -14.111928
#
# --- Iteration 4 ---
# Tridiagonal matrix diagonal element at [3, 3] = -0.461729
# Tridiagonal matrix off-diagonal element at [4, 3] = 10.191114
# Estimated eigenvalue: -16.326273
#
# --- Iteration 5 ---
# Tridiagonal matrix diagonal element at [4, 4] = -0.143106
# Tridiagonal matrix off-diagonal element at [5, 4] = 9.998447
# Estimated eigenvalue: -17.616807
#
# --- Iteration 6 ---
# Tridiagonal matrix diagonal element at [5, 5] = -0.044337
# Tridiagonal matrix off-diagonal element at [6, 5] = 10.099428
# Estimated eigenvalue: -18.360143
#
# --- Iteration 7 ---
# Tridiagonal matrix diagonal element at [6, 6] = -0.014623
# Tridiagonal matrix off-diagonal element at [7, 6] = 10.033533
# Estimated eigenvalue: -18.819064
#
# --- Iteration 8 ---
# Tridiagonal matrix diagonal element at [7, 7] = 0.056483
# Tridiagonal matrix off-diagonal element at [8, 7] = 10.175859
# Estimated eigenvalue: -19.114245
#
# --- Iteration 9 ---
# Tridiagonal matrix diagonal element at [8, 8] = -0.165202
# Tridiagonal matrix off-diagonal element at [9, 8] = 10.142514
# Estimated eigenvalue: -19.324586
#
# --- Iteration 10 ---
# Tridiagonal matrix diagonal element at [9, 9] = -0.268667
# Tridiagonal matrix off-diagonal element at [10, 9] = 10.108353
# Estimated eigenvalue: -19.487898
#
# --- Iteration 11 ---
# Tridiagonal matrix diagonal element at [10, 10] = -0.224067
# Tridiagonal matrix off-diagonal element at [11, 10] = 10.057400
# Estimated eigenvalue: -19.620548
#
# --- Iteration 12 ---
# Tridiagonal matrix diagonal element at [11, 11] = -0.100168
# Tridiagonal matrix off-diagonal element at [12, 11] = 10.074990
# Estimated eigenvalue: -19.727379
#
# --- Iteration 13 ---
# Tridiagonal matrix diagonal element at [12, 12] = -0.039117
# Tridiagonal matrix off-diagonal element at [13, 12] = 10.043912
# Estimated eigenvalue: -19.811915
#
# --- Iteration 14 ---
# Tridiagonal matrix diagonal element at [13, 13] = -0.108040
# Tridiagonal matrix off-diagonal element at [14, 13] = 10.246367
# Estimated eigenvalue: -19.877661
#
# --- Iteration 15 ---
# Tridiagonal matrix diagonal element at [14, 14] = -0.042436
# Tridiagonal matrix off-diagonal element at [15, 14] = 10.049303
# Estimated eigenvalue: -19.932259
#
# --- Iteration 16 ---
# Tridiagonal matrix diagonal element at [15, 15] = 0.059594
# Tridiagonal matrix off-diagonal element at [16, 15] = 10.085339
# Estimated eigenvalue: -19.976178
#
# --- Iteration 17 ---
# Tridiagonal matrix diagonal element at [16, 16] = -0.155260
# Tridiagonal matrix off-diagonal element at [17, 16] = 10.041531
# Estimated eigenvalue: -20.011540
#
# --- Iteration 18 ---
# Tridiagonal matrix diagonal element at [17, 17] = 0.046080
# Tridiagonal matrix off-diagonal element at [18, 17] = 10.098762
# Estimated eigenvalue: -20.039742
#
# --- Iteration 19 ---
# Tridiagonal matrix diagonal element at [18, 18] = -0.160511
# Tridiagonal matrix off-diagonal element at [19, 18] = 10.016708
# Estimated eigenvalue: -20.062629
#
# --- Iteration 20 ---
# Tridiagonal matrix diagonal element at [19, 19] = 0.067032
# Tridiagonal matrix off-diagonal element at [20, 19] = 10.048194
# Estimated eigenvalue: -20.080939
#
# --- Iteration 21 ---
# Tridiagonal matrix diagonal element at [20, 20] = 0.084754
# Tridiagonal matrix off-diagonal element at [21, 20] = 10.005790
# Estimated eigenvalue: -20.095313
#
# --- Iteration 22 ---
# Tridiagonal matrix diagonal element at [21, 21] = -0.107373
# Tridiagonal matrix off-diagonal element at [22, 21] = 10.125883
# Estimated eigenvalue: -20.106477
#
# --- Iteration 23 ---
# Tridiagonal matrix diagonal element at [22, 22] = -0.166217
# Tridiagonal matrix off-diagonal element at [23, 22] = 10.187943
# Estimated eigenvalue: -20.115680
#
# --- Iteration 24 ---
# Tridiagonal matrix diagonal element at [23, 23] = 0.120255
# Tridiagonal matrix off-diagonal element at [24, 23] = 9.965049
# Estimated eigenvalue: -20.123670
#
# --- Iteration 25 ---
# Tridiagonal matrix diagonal element at [24, 24] = -0.043210
# Tridiagonal matrix off-diagonal element at [25, 24] = 10.083315
# Estimated eigenvalue: -20.130269
#
# --- Iteration 26 ---
# Tridiagonal matrix diagonal element at [25, 25] = -0.253382
# Tridiagonal matrix off-diagonal element at [26, 25] = 10.101713
# Estimated eigenvalue: -20.135923
#
# --- Iteration 27 ---
# Tridiagonal matrix diagonal element at [26, 26] = -0.097311
# Tridiagonal matrix off-diagonal element at [27, 26] = 10.104392
# Estimated eigenvalue: -20.140983
#
# --- Iteration 28 ---
# Tridiagonal matrix diagonal element at [27, 27] = -0.116690
# Tridiagonal matrix off-diagonal element at [28, 27] = 10.116051
# Estimated eigenvalue: -20.145629
#
# --- Iteration 29 ---
# Tridiagonal matrix diagonal element at [28, 28] = 0.171889
# Tridiagonal matrix off-diagonal element at [29, 28] = 10.099114
# Estimated eigenvalue: -20.149904
#
# --- Iteration 30 ---
# Tridiagonal matrix diagonal element at [29, 29] = 0.206093
# Tridiagonal matrix off-diagonal element at [30, 29] = 10.120474
# Estimated eigenvalue: -20.153697
#
# --- Iteration 31 ---
# Tridiagonal matrix diagonal element at [30, 30] = 0.169372
# Tridiagonal matrix off-diagonal element at [31, 30] = 10.199505
# Estimated eigenvalue: -20.156985
#
# --- Iteration 32 ---
# Tridiagonal matrix diagonal element at [31, 31] = 0.162134
# Tridiagonal matrix off-diagonal element at [32, 31] = 9.946796
# Estimated eigenvalue: -20.159873
#
# --- Iteration 33 ---
# Tridiagonal matrix diagonal element at [32, 32] = 0.098439
# Tridiagonal matrix off-diagonal element at [33, 32] = 10.143540
# Estimated eigenvalue: -20.162230
#
# --- Iteration 34 ---
# Tridiagonal matrix diagonal element at [33, 33] = 0.092438
# Tridiagonal matrix off-diagonal element at [34, 33] = 10.161850
# Estimated eigenvalue: -20.164186
#
# --- Iteration 35 ---
# Tridiagonal matrix diagonal element at [34, 34] = 0.057328
# Tridiagonal matrix off-diagonal element at [35, 34] = 10.034499
# Estimated eigenvalue: -20.165853
#
# --- Iteration 36 ---
# Tridiagonal matrix diagonal element at [35, 35] = -0.014785
# Tridiagonal matrix off-diagonal element at [36, 35] = 9.956413
# Estimated eigenvalue: -20.167251
#
# --- Iteration 37 ---
# Tridiagonal matrix diagonal element at [36, 36] = 0.053751
# Tridiagonal matrix off-diagonal element at [37, 36] = 10.050280
# Estimated eigenvalue: -20.168379
#
# --- Iteration 38 ---
# Tridiagonal matrix diagonal element at [37, 37] = 0.095509
# Tridiagonal matrix off-diagonal element at [38, 37] = 9.999775
# Estimated eigenvalue: -20.169282
#
# --- Iteration 39 ---
# Tridiagonal matrix diagonal element at [38, 38] = -0.194030
# Tridiagonal matrix off-diagonal element at [39, 38] = 10.084153
# Estimated eigenvalue: -20.170004
#
# --- Iteration 40 ---
# Tridiagonal matrix diagonal element at [39, 39] = -0.075973
# Tridiagonal matrix off-diagonal element at [40, 39] = 10.103061
# Estimated eigenvalue: -20.170607
#
# --- Iteration 41 ---
# Tridiagonal matrix diagonal element at [40, 40] = -0.125952
# Tridiagonal matrix off-diagonal element at [41, 40] = 9.928838
# Estimated eigenvalue: -20.171131
#
# --- Iteration 42 ---
# Tridiagonal matrix diagonal element at [41, 41] = -0.107548
# Tridiagonal matrix off-diagonal element at [42, 41] = 10.186976
# Estimated eigenvalue: -20.171574
#
# --- Iteration 43 ---
# Tridiagonal matrix diagonal element at [42, 42] = 0.242581
# Tridiagonal matrix off-diagonal element at [43, 42] = 10.111223
# Estimated eigenvalue: -20.171961
#
# --- Iteration 44 ---
# Tridiagonal matrix diagonal element at [43, 43] = -0.104719
# Tridiagonal matrix off-diagonal element at [44, 43] = 10.074232
# Estimated eigenvalue: -20.172301
#
# --- Iteration 45 ---
# Tridiagonal matrix diagonal element at [44, 44] = -0.051478
# Tridiagonal matrix off-diagonal element at [45, 44] = 10.097782
# Estimated eigenvalue: -20.172606
#
# --- Iteration 46 ---
# Tridiagonal matrix diagonal element at [45, 45] = 0.113729
# Tridiagonal matrix off-diagonal element at [46, 45] = 10.087408
# Estimated eigenvalue: -20.172879
#
# --- Iteration 47 ---
# Tridiagonal matrix diagonal element at [46, 46] = 0.013920
# Tridiagonal matrix off-diagonal element at [47, 46] = 10.165313
# Estimated eigenvalue: -20.173122
#
# --- Iteration 48 ---
# Tridiagonal matrix diagonal element at [47, 47] = -0.034451
# Tridiagonal matrix off-diagonal element at [48, 47] = 10.098675
# Estimated eigenvalue: -20.173347
#
# --- Iteration 49 ---
# Tridiagonal matrix diagonal element at [48, 48] = -0.055692
# Tridiagonal matrix off-diagonal element at [49, 48] = 10.077870
# Estimated eigenvalue: -20.173558
#
# --- Iteration 50 ---
# Tridiagonal matrix diagonal element at [49, 49] = -0.057654
# Tridiagonal matrix off-diagonal element at [50, 49] = 10.143179
# Estimated eigenvalue: -20.173758
#
# --- Iteration 51 ---
# Tridiagonal matrix diagonal element at [50, 50] = -0.222494
# Tridiagonal matrix off-diagonal element at [51, 50] = 10.118115
# Estimated eigenvalue: -20.173957
#
# --- Iteration 52 ---
# Tridiagonal matrix diagonal element at [51, 51] = -0.093626
# Tridiagonal matrix off-diagonal element at [52, 51] = 10.123424
# Estimated eigenvalue: -20.174164
#
# --- Iteration 53 ---
# Tridiagonal matrix diagonal element at [52, 52] = -0.207794
# Tridiagonal matrix off-diagonal element at [53, 52] = 10.085198
# Estimated eigenvalue: -20.174388
#
# --- Iteration 54 ---
# Tridiagonal matrix diagonal element at [53, 53] = -0.149382
# Tridiagonal matrix off-diagonal element at [54, 53] = 10.176183
# Estimated eigenvalue: -20.174642
#
# --- Iteration 55 ---
# Tridiagonal matrix diagonal element at [54, 54] = 0.075043
# Tridiagonal matrix off-diagonal element at [55, 54] = 10.239561
# Estimated eigenvalue: -20.174945
#
# --- Iteration 56 ---
# Tridiagonal matrix diagonal element at [55, 55] = 0.161404
# Tridiagonal matrix off-diagonal element at [56, 55] = 10.170414
# Estimated eigenvalue: -20.175324
#
# --- Iteration 57 ---
# Tridiagonal matrix diagonal element at [56, 56] = 0.100017
# Tridiagonal matrix off-diagonal element at [57, 56] = 10.065736
# Estimated eigenvalue: -20.175815
#
# --- Iteration 58 ---
# Tridiagonal matrix diagonal element at [57, 57] = 0.149510
# Tridiagonal matrix off-diagonal element at [58, 57] = 10.130648
# Estimated eigenvalue: -20.176443
#
# --- Iteration 59 ---
# Tridiagonal matrix diagonal element at [58, 58] = -0.018031
# Tridiagonal matrix off-diagonal element at [59, 58] = 10.060743
# Estimated eigenvalue: -20.177264
#
# --- Iteration 60 ---
# Tridiagonal matrix diagonal element at [59, 59] = 0.132141
# Tridiagonal matrix off-diagonal element at [60, 59] = 10.235630
# Estimated eigenvalue: -20.178323
#
# --- Iteration 61 ---
# Tridiagonal matrix diagonal element at [60, 60] = -0.047337
# Tridiagonal matrix off-diagonal element at [61, 60] = 10.115917
# Estimated eigenvalue: -20.179753
#
# --- Iteration 62 ---
# Tridiagonal matrix diagonal element at [61, 61] = -0.174181
# Tridiagonal matrix off-diagonal element at [62, 61] = 10.063341
# Estimated eigenvalue: -20.181712
#
# --- Iteration 63 ---
# Tridiagonal matrix diagonal element at [62, 62] = 0.129649
# Tridiagonal matrix off-diagonal element at [63, 62] = 10.182299
# Estimated eigenvalue: -20.184233
#
# --- Iteration 64 ---
# Tridiagonal matrix diagonal element at [63, 63] = -0.119811
# Tridiagonal matrix off-diagonal element at [64, 63] = 10.134456
# Estimated eigenvalue: -20.187297
#
# --- Iteration 65 ---
# Tridiagonal matrix diagonal element at [64, 64] = 0.088848
# Tridiagonal matrix off-diagonal element at [65, 64] = 10.089851
# Estimated eigenvalue: -20.190732
#
# --- Iteration 66 ---
# Tridiagonal matrix diagonal element at [65, 65] = 0.082671
# Tridiagonal matrix off-diagonal element at [66, 65] = 10.228851
# Estimated eigenvalue: -20.194200
#
# --- Iteration 67 ---
# Tridiagonal matrix diagonal element at [66, 66] = -0.036026
# Tridiagonal matrix off-diagonal element at [67, 66] = 10.156650
# Estimated eigenvalue: -20.197657
#
# --- Iteration 68 ---
# Tridiagonal matrix diagonal element at [67, 67] = -0.138177
# Tridiagonal matrix off-diagonal element at [68, 67] = 10.139196
# Estimated eigenvalue: -20.201098
#
# --- Iteration 69 ---
# Tridiagonal matrix diagonal element at [68, 68] = -0.047374
# Tridiagonal matrix off-diagonal element at [69, 68] = 10.105623
# Estimated eigenvalue: -20.204533
#
# --- Iteration 70 ---
# Tridiagonal matrix diagonal element at [69, 69] = -0.035390
# Tridiagonal matrix off-diagonal element at [70, 69] = 10.180931
# Estimated eigenvalue: -20.207907
#
# --- Iteration 71 ---
# Tridiagonal matrix diagonal element at [70, 70] = 0.140586
# Tridiagonal matrix off-diagonal element at [71, 70] = 10.196986
# Estimated eigenvalue: -20.211216
#
# --- Iteration 72 ---
# Tridiagonal matrix diagonal element at [71, 71] = 0.030991
# Tridiagonal matrix off-diagonal element at [72, 71] = 10.014266
# Estimated eigenvalue: -20.214457
#
# --- Iteration 73 ---
# Tridiagonal matrix diagonal element at [72, 72] = 0.073271
# Tridiagonal matrix off-diagonal element at [73, 72] = 10.047734
# Estimated eigenvalue: -20.217436
#
# --- Iteration 74 ---
# Tridiagonal matrix diagonal element at [73, 73] = -0.169221
# Tridiagonal matrix off-diagonal element at [74, 73] = 10.107567
# Estimated eigenvalue: -20.220103
#
# --- Iteration 75 ---
# Tridiagonal matrix diagonal element at [74, 74] = 0.147141
# Tridiagonal matrix off-diagonal element at [75, 74] = 10.122666
# Estimated eigenvalue: -20.222479
#
# --- Iteration 76 ---
# Tridiagonal matrix diagonal element at [75, 75] = -0.010169
# Tridiagonal matrix off-diagonal element at [76, 75] = 10.032422
# Estimated eigenvalue: -20.224568
#
# --- Iteration 77 ---
# Tridiagonal matrix diagonal element at [76, 76] = 0.021963
# Tridiagonal matrix off-diagonal element at [77, 76] = 10.080135
# Estimated eigenvalue: -20.226347
#
# --- Iteration 78 ---
# Tridiagonal matrix diagonal element at [77, 77] = 0.148899
# Tridiagonal matrix off-diagonal element at [78, 77] = 10.140901
# Estimated eigenvalue: -20.227829
#
# --- Iteration 79 ---
# Tridiagonal matrix diagonal element at [78, 78] = 0.012935
# Tridiagonal matrix off-diagonal element at [79, 78] = 9.996068
# Estimated eigenvalue: -20.229070
#
# --- Iteration 80 ---
# Tridiagonal matrix diagonal element at [79, 79] = 0.076613
# Tridiagonal matrix off-diagonal element at [80, 79] = 9.976978
# Estimated eigenvalue: -20.230067
#
# --- Iteration 81 ---
# Tridiagonal matrix diagonal element at [80, 80] = -0.008216
# Tridiagonal matrix off-diagonal element at [81, 80] = 10.021519
# Estimated eigenvalue: -20.230839
#
# --- Iteration 82 ---
# Tridiagonal matrix diagonal element at [81, 81] = -0.260673
# Tridiagonal matrix off-diagonal element at [82, 81] = 10.048014
# Estimated eigenvalue: -20.231448
#
# --- Iteration 83 ---
# Tridiagonal matrix diagonal element at [82, 82] = 0.043146
# Tridiagonal matrix off-diagonal element at [83, 82] = 10.036006
# Estimated eigenvalue: -20.231937
#
# --- Iteration 84 ---
# Tridiagonal matrix diagonal element at [83, 83] = 0.001818
# Tridiagonal matrix off-diagonal element at [84, 83] = 10.117453
# Estimated eigenvalue: -20.232325
#
# --- Iteration 85 ---
# Tridiagonal matrix diagonal element at [84, 84] = -0.098792
# Tridiagonal matrix off-diagonal element at [85, 84] = 10.152246
# Estimated eigenvalue: -20.232643
#
# --- Iteration 86 ---
# Tridiagonal matrix diagonal element at [85, 85] = -0.017039
# Tridiagonal matrix off-diagonal element at [86, 85] = 10.068918
# Estimated eigenvalue: -20.232914
#
# --- Iteration 87 ---
# Tridiagonal matrix diagonal element at [86, 86] = -0.137338
# Tridiagonal matrix off-diagonal element at [87, 86] = 10.098313
# Estimated eigenvalue: -20.233148
#
# --- Iteration 88 ---
# Tridiagonal matrix diagonal element at [87, 87] = -0.265756
# Tridiagonal matrix off-diagonal element at [88, 87] = 9.986305
# Estimated eigenvalue: -20.233357
#
# --- Iteration 89 ---
# Tridiagonal matrix diagonal element at [88, 88] = 0.095896
# Tridiagonal matrix off-diagonal element at [89, 88] = 10.062924
# Estimated eigenvalue: -20.233540
#
# --- Iteration 90 ---
# Tridiagonal matrix diagonal element at [89, 89] = 0.214206
# Tridiagonal matrix off-diagonal element at [90, 89] = 10.104480
# Estimated eigenvalue: -20.233693
#
# --- Iteration 91 ---
# Tridiagonal matrix diagonal element at [90, 90] = -0.356575
# Tridiagonal matrix off-diagonal element at [91, 90] = 10.144186
# Estimated eigenvalue: -20.233823
#
# --- Iteration 92 ---
# Tridiagonal matrix diagonal element at [91, 91] = 0.251573
# Tridiagonal matrix off-diagonal element at [92, 91] = 10.218436
# Estimated eigenvalue: -20.233939
#
# --- Iteration 93 ---
# Tridiagonal matrix diagonal element at [92, 92] = 0.047925
# Tridiagonal matrix off-diagonal element at [93, 92] = 10.029162
# Estimated eigenvalue: -20.234043
#
# --- Iteration 94 ---
# Tridiagonal matrix diagonal element at [93, 93] = -0.081279
# Tridiagonal matrix off-diagonal element at [94, 93] = 10.070370
# Estimated eigenvalue: -20.234134
#
# --- Iteration 95 ---
# Tridiagonal matrix diagonal element at [94, 94] = -0.174386
# Tridiagonal matrix off-diagonal element at [95, 94] = 9.996040
# Estimated eigenvalue: -20.234215
#
# --- Iteration 96 ---
# Tridiagonal matrix diagonal element at [95, 95] = -0.182787
# Tridiagonal matrix off-diagonal element at [96, 95] = 9.956742
# Estimated eigenvalue: -20.234287
#
# --- Iteration 97 ---
# Tridiagonal matrix diagonal element at [96, 96] = -0.099978
# Tridiagonal matrix off-diagonal element at [97, 96] = 9.973833
# Estimated eigenvalue: -20.234349
#
# --- Iteration 98 ---
# Tridiagonal matrix diagonal element at [97, 97] = 0.080712
# Tridiagonal matrix off-diagonal element at [98, 97] = 10.071386
# Estimated eigenvalue: -20.234400
#
# --- Iteration 99 ---
# Tridiagonal matrix diagonal element at [98, 98] = -0.023034
# Tridiagonal matrix off-diagonal element at [99, 98] = 10.103776
# Estimated eigenvalue: -20.234442
#
# --- Iteration 100 ---
# Tridiagonal matrix diagonal element at [99, 99] = 0.077170
# Tridiagonal matrix off-diagonal element at [100, 99] = 10.033865
# Estimated eigenvalue: -20.234476
#
# --- Iteration 101 ---
# Tridiagonal matrix diagonal element at [100, 100] = 0.166313
# Tridiagonal matrix off-diagonal element at [101, 100] = 10.123920
# Estimated eigenvalue: -20.234504
#
# --- Iteration 102 ---
# Tridiagonal matrix diagonal element at [101, 101] = 0.002582
# Tridiagonal matrix off-diagonal element at [102, 101] = 10.277207
# Estimated eigenvalue: -20.234526
#
# --- Iteration 103 ---
# Tridiagonal matrix diagonal element at [102, 102] = 0.326411
# Tridiagonal matrix off-diagonal element at [103, 102] = 10.082018
# Estimated eigenvalue: -20.234545
#
# --- Iteration 104 ---
# Tridiagonal matrix diagonal element at [103, 103] = 0.078583
# Tridiagonal matrix off-diagonal element at [104, 103] = 10.218968
# Estimated eigenvalue: -20.234561
#
# --- Iteration 105 ---
# Tridiagonal matrix diagonal element at [104, 104] = 0.121805
# Tridiagonal matrix off-diagonal element at [105, 104] = 10.160993
# Estimated eigenvalue: -20.234574
#
# --- Iteration 106 ---
# Tridiagonal matrix diagonal element at [105, 105] = 0.006085
# Tridiagonal matrix off-diagonal element at [106, 105] = 9.982290
# Estimated eigenvalue: -20.234585
#
# --- Iteration 107 ---
# Tridiagonal matrix diagonal element at [106, 106] = -0.044252
# Tridiagonal matrix off-diagonal element at [107, 106] = 10.069382
# Estimated eigenvalue: -20.234595
#
# --- Iteration 108 ---
# Tridiagonal matrix diagonal element at [107, 107] = 0.091623
# Tridiagonal matrix off-diagonal element at [108, 107] = 10.140131
# Estimated eigenvalue: -20.234603
#
# --- Iteration 109 ---
# Tridiagonal matrix diagonal element at [108, 108] = 0.211749
# Tridiagonal matrix off-diagonal element at [109, 108] = 10.109594
# Estimated eigenvalue: -20.234609
#
# --- Iteration 110 ---
# Tridiagonal matrix diagonal element at [109, 109] = 0.018369
# Tridiagonal matrix off-diagonal element at [110, 109] = 10.086844
# Estimated eigenvalue: -20.234614
#
# --- Iteration 111 ---
# Tridiagonal matrix diagonal element at [110, 110] = -0.191065
# Tridiagonal matrix off-diagonal element at [111, 110] = 10.131326
# Estimated eigenvalue: -20.234619
#
# --- Iteration 112 ---
# Tridiagonal matrix diagonal element at [111, 111] = 0.114257
# Tridiagonal matrix off-diagonal element at [112, 111] = 9.976951
# Estimated eigenvalue: -20.234622
#
# --- Iteration 113 ---
# Tridiagonal matrix diagonal element at [112, 112] = -0.060755
# Tridiagonal matrix off-diagonal element at [113, 112] = 10.184205
# Estimated eigenvalue: -20.234626
#
# --- Iteration 114 ---
# Tridiagonal matrix diagonal element at [113, 113] = 0.096775
# Tridiagonal matrix off-diagonal element at [114, 113] = 9.957085
# Estimated eigenvalue: -20.234628
#
# --- Iteration 115 ---
# Tridiagonal matrix diagonal element at [114, 114] = 0.000919
# Tridiagonal matrix off-diagonal element at [115, 114] = 10.092057
# Estimated eigenvalue: -20.234630
#
# --- Iteration 116 ---
# Tridiagonal matrix diagonal element at [115, 115] = 0.121847
# Tridiagonal matrix off-diagonal element at [116, 115] = 9.926911
# Estimated eigenvalue: -20.234632
#
# --- Iteration 117 ---
# Tridiagonal matrix diagonal element at [116, 116] = -0.108333
# Tridiagonal matrix off-diagonal element at [117, 116] = 9.905849
# Estimated eigenvalue: -20.234633
#
# --- Iteration 118 ---
# Tridiagonal matrix diagonal element at [117, 117] = -0.144000
# Tridiagonal matrix off-diagonal element at [118, 117] = 9.993335
# Estimated eigenvalue: -20.234634
#
# --- Iteration 119 ---
# Tridiagonal matrix diagonal element at [118, 118] = -0.259420
# Tridiagonal matrix off-diagonal element at [119, 118] = 9.996187
# Estimated eigenvalue: -20.234635
#
# --- Iteration 120 ---
# Tridiagonal matrix diagonal element at [119, 119] = 0.226503
# Tridiagonal matrix off-diagonal element at [120, 119] = 10.094838
# Estimated eigenvalue: -20.234636
#
# --- Iteration 121 ---
# Tridiagonal matrix diagonal element at [120, 120] = -0.167354
# Tridiagonal matrix off-diagonal element at [121, 120] = 10.075472
# Estimated eigenvalue: -20.234636
#
# --- Iteration 122 ---
# Tridiagonal matrix diagonal element at [121, 121] = 0.067703
# Tridiagonal matrix off-diagonal element at [122, 121] = 9.904105
# Estimated eigenvalue: -20.234637
#
# --- Iteration 123 ---
# Tridiagonal matrix diagonal element at [122, 122] = -0.105885
# Tridiagonal matrix off-diagonal element at [123, 122] = 9.940615
# Estimated eigenvalue: -20.234637
# Converged after 123 iterations with eigenvalue -20.234637
# Number of iterations for trial 2: 123
# Density: 1.00%, Average Lanczos Basis Size: 123.0
#
# --- Evaluating Density Level: 5.00% ---
#
# Trial 1 for density level 5.00%
# Generating sparse matrix with size 10000 and density 5.00%
