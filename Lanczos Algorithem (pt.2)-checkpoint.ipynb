# %%
import numpy as np
from scipy.sparse import random as sparse_random
from scipy.sparse.linalg import eigsh
import matplotlib.pyplot as plt

def generate_sparse_matrix(size, density):
    diagonal_values = np.linspace(-1, 1, size)
    rvs = np.random.randn  
    upper = sparse_random(size, size, density=density/2, data_rvs=rvs, format='coo')
    matrix_s = upper + upper.T
    matrix_s.setdiag(diagonal_values)
    
    return matrix_s.tocsr()  

def lanczos_algorithm(matrix_s, initial_vector, expected_eigenvalue, tol=0, max_iter=10000):
    m = matrix_s.shape[0]
    krylov_vectors = np.zeros((m, max_iter + 1))
    tridiag_matrix = np.zeros((max_iter + 1, max_iter))
    w = initial_vector / np.linalg.norm(initial_vector)
    krylov_vectors[:, 0] = w
    
    for k in range(max_iter):
        v = matrix_s.dot(krylov_vectors[:, k])
        tridiag_matrix[k, k] = np.dot(krylov_vectors[:, k].conj(), v)
        v = v - tridiag_matrix[k, k] * krylov_vectors[:, k]
        if k > 0:
            v = v - tridiag_matrix[k, k-1] * krylov_vectors[:, k-1]
        tridiag_matrix[k + 1, k] = np.linalg.norm(v)
        if tridiag_matrix[k + 1, k] > tol:
            krylov_vectors[:, k + 1] = v / tridiag_matrix[k + 1, k]
        else:
            print(f"Convergence reached at iteration {k+1}, stopping Lanczos.")
            break
        
        eigenvalues = np.linalg.eigvalsh(tridiag_matrix[:k + 1, :k + 1])
        estimated_eigenvalue = eigenvalues[0]

        if abs(estimated_eigenvalue - expected_eigenvalue) < tol:
            return k + 1
        if estimated_eigenvalue<=expected_eigenvalue:
            return k + 1
    
    return max_iter

def evaluate_average_iterations(size, density_levels, initial_vector, num_trials=10, tol=0, max_iter=10000):
    avg_iterations_per_density = []
    
    for density in density_levels:
        print(f"\n--- Evaluating Density Level: {density*100:.10g}% ---")
        total_iterations = 0
        for trial in range(num_trials):
            matrix_s = generate_sparse_matrix(size, density)
            exact_eigenvalue, _ = eigsh(matrix_s, k=1, which='SA', tol=0)
            exact_eigenvalue = exact_eigenvalue[0]
            
            num_iterations = lanczos_algorithm(matrix_s, initial_vector, exact_eigenvalue, tol, max_iter)
            total_iterations += num_iterations
        
        avg_iterations = total_iterations / num_trials
        avg_iterations_per_density.append(avg_iterations)
        print(f"Density: {density*100:.10g}%, Average Lanczos Basis Size: {avg_iterations}")
    
    return avg_iterations_per_density

# Parameters
size = 10000
density_levels = [0.00001]
density = 0.00005
density_2 = 0.0
while density <= 0.001:
    density_levels.append(density)
    density += 0.00005
while density <= 0.0105:
    density_levels.append(density)
    density += 0.0005 
'''if density == 0.0095:
    density += 0.0005
    density_levels.append(density)'''
while density_2 <= 1.0:
    density_2 += 0.05 
    density_levels.append(density_2)
while density_2<=1.0:
    break
initial_vector = np.random.rand(size)  # random initial vector

# Evaluate the basis size for different sparsity levels
average_basis_sizes = evaluate_average_iterations(size, density_levels, initial_vector, num_trials=10)

# Plot the results
plt.figure(figsize=(12, 8))
plt.plot([d*100 for d in density_levels], average_basis_sizes, marker='o', linestyle='-', color='b')
plt.xlabel('Density Level (%)')
plt.ylabel('Average Lanczos Basis Size')
plt.title('Density vs Average Lanczos Basis Size')
plt.grid(True)
plt.xticks([d*100 for d in density_levels], rotation=45, ha="right")  
plt.tight_layout() 
plt.show()
# Out:
# --- Evaluating Density Level: 0.001% ---
# Density: 0.001%, Average Lanczos Basis Size: 53.7
#
# --- Evaluating Density Level: 0.005% ---
# Density: 0.005%, Average Lanczos Basis Size: 59.8
#
# --- Evaluating Density Level: 0.01% ---
# Density: 0.01%, Average Lanczos Basis Size: 75.7
#
# --- Evaluating Density Level: 0.015% ---
# Density: 0.015%, Average Lanczos Basis Size: 95.9
#
# --- Evaluating Density Level: 0.02% ---
# Density: 0.02%, Average Lanczos Basis Size: 75.0
#
# --- Evaluating Density Level: 0.025% ---
# Density: 0.025%, Average Lanczos Basis Size: 84.5
#
# --- Evaluating Density Level: 0.03% ---
# Density: 0.03%, Average Lanczos Basis Size: 87.8
#
# --- Evaluating Density Level: 0.035% ---
# Density: 0.035%, Average Lanczos Basis Size: 86.1
#
# --- Evaluating Density Level: 0.04% ---
# Density: 0.04%, Average Lanczos Basis Size: 87.9
#
# --- Evaluating Density Level: 0.045% ---
# Density: 0.045%, Average Lanczos Basis Size: 106.2
#
# --- Evaluating Density Level: 0.05% ---
# Density: 0.05%, Average Lanczos Basis Size: 93.4
#
# --- Evaluating Density Level: 0.055% ---
# Density: 0.055%, Average Lanczos Basis Size: 104.7
#
# --- Evaluating Density Level: 0.06% ---
# Density: 0.06%, Average Lanczos Basis Size: 128.0
#
# --- Evaluating Density Level: 0.065% ---
# Density: 0.065%, Average Lanczos Basis Size: 87.6
#
# --- Evaluating Density Level: 0.07% ---
# Density: 0.07%, Average Lanczos Basis Size: 94.9
#
# --- Evaluating Density Level: 0.075% ---
# Density: 0.075%, Average Lanczos Basis Size: 90.2
#
# --- Evaluating Density Level: 0.08% ---
# Density: 0.08%, Average Lanczos Basis Size: 94.5
#
# --- Evaluating Density Level: 0.085% ---
# Density: 0.085%, Average Lanczos Basis Size: 146.3
#
# --- Evaluating Density Level: 0.09% ---
# Density: 0.09%, Average Lanczos Basis Size: 131.7
#
# --- Evaluating Density Level: 0.095% ---
# Density: 0.095%, Average Lanczos Basis Size: 109.4
#
# --- Evaluating Density Level: 0.1% ---
# Density: 0.1%, Average Lanczos Basis Size: 153.4
#
# --- Evaluating Density Level: 0.15% ---
# Density: 0.15%, Average Lanczos Basis Size: 116.6
#
# --- Evaluating Density Level: 0.2% ---
# Density: 0.2%, Average Lanczos Basis Size: 128.8
#
# --- Evaluating Density Level: 0.25% ---
# Density: 0.25%, Average Lanczos Basis Size: 198.5
#
# --- Evaluating Density Level: 0.3% ---
# Density: 0.3%, Average Lanczos Basis Size: 206.7
#
# --- Evaluating Density Level: 0.35% ---
# Density: 0.35%, Average Lanczos Basis Size: 163.3
#
# --- Evaluating Density Level: 0.4% ---
# Density: 0.4%, Average Lanczos Basis Size: 189.5
#
# --- Evaluating Density Level: 0.45% ---
# Density: 0.45%, Average Lanczos Basis Size: 216.9
#
# --- Evaluating Density Level: 0.5% ---
# Density: 0.5%, Average Lanczos Basis Size: 289.9
#
# --- Evaluating Density Level: 0.55% ---
# Density: 0.55%, Average Lanczos Basis Size: 298.5
#
# --- Evaluating Density Level: 0.6% ---
# Density: 0.6%, Average Lanczos Basis Size: 288.5
#
# --- Evaluating Density Level: 0.65% ---
# Density: 0.65%, Average Lanczos Basis Size: 230.2
#
# --- Evaluating Density Level: 0.7% ---
# Density: 0.7%, Average Lanczos Basis Size: 389.6
#
# --- Evaluating Density Level: 0.75% ---
# Density: 0.75%, Average Lanczos Basis Size: 196.8
#
# --- Evaluating Density Level: 0.8% ---
# Density: 0.8%, Average Lanczos Basis Size: 332.5
#
# --- Evaluating Density Level: 0.85% ---
# Density: 0.85%, Average Lanczos Basis Size: 230.7
#
# --- Evaluating Density Level: 0.9% ---
# Density: 0.9%, Average Lanczos Basis Size: 375.0
#
# --- Evaluating Density Level: 0.95% ---
# Density: 0.95%, Average Lanczos Basis Size: 287.0
#
# --- Evaluating Density Level: 1% ---
# Density: 1%, Average Lanczos Basis Size: 331.1
#
# --- Evaluating Density Level: 5% ---
# Density: 5%, Average Lanczos Basis Size: 422.7
#
# --- Evaluating Density Level: 10% ---
# Density: 10%, Average Lanczos Basis Size: 105.5
#
# --- Evaluating Density Level: 15% ---
# Density: 15%, Average Lanczos Basis Size: 118.5
#
# --- Evaluating Density Level: 20% ---
# Density: 20%, Average Lanczos Basis Size: 132.6
#
# --- Evaluating Density Level: 25% ---
# Density: 25%, Average Lanczos Basis Size: 111.2
#
# --- Evaluating Density Level: 30% ---
# Density: 30%, Average Lanczos Basis Size: 118.7
#
# --- Evaluating Density Level: 35% ---
# Density: 35%, Average Lanczos Basis Size: 138.8
#
# --- Evaluating Density Level: 40% ---
# Density: 40%, Average Lanczos Basis Size: 172.8
#
# --- Evaluating Density Level: 45% ---
# Density: 45%, Average Lanczos Basis Size: 130.1
#
# --- Evaluating Density Level: 50% ---
# Density: 50%, Average Lanczos Basis Size: 107.7
#
# --- Evaluating Density Level: 55% ---
# Density: 55%, Average Lanczos Basis Size: 94.3
#
# --- Evaluating Density Level: 60% ---
# Density: 60%, Average Lanczos Basis Size: 99.6
#
# --- Evaluating Density Level: 65% ---
# Density: 65%, Average Lanczos Basis Size: 127.1
#
# --- Evaluating Density Level: 70% ---
# Density: 70%, Average Lanczos Basis Size: 109.1
#
# --- Evaluating Density Level: 75% ---
# Density: 75%, Average Lanczos Basis Size: 111.5
#
# --- Evaluating Density Level: 80% ---
# Density: 80%, Average Lanczos Basis Size: 117.4
#
# --- Evaluating Density Level: 85% ---
# Density: 85%, Average Lanczos Basis Size: 139.8
#
# --- Evaluating Density Level: 90% ---
# Density: 90%, Average Lanczos Basis Size: 111.0
#
# --- Evaluating Density Level: 95% ---
# Density: 95%, Average Lanczos Basis Size: 95.8
#
# --- Evaluating Density Level: 100% ---
# Density: 100%, Average Lanczos Basis Size: 157.8
