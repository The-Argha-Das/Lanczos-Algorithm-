# %%
import pandas as pd
import matplotlib.pyplot as plt
data = [
    (0.01, 246.90, 0.6265),
    (0.05, 244.70, 1.1065),
    (0.10, 269.48, 2.1689),
    (0.15, 285.62, 2.9798),
    (0.20, 260.35, 3.3901),
    (0.25, 320.00, 4.6145),
    (0.30, 265.43, 4.2291),
    (0.35, 257.82, 4.6112),
    (0.40, 270.80, 5.3705),
    (0.45, 269.50, 5.8306),
    (0.50, 274.93, 6.4819),
    (0.55, 268.60, 6.9720),
    (0.60, 275.80, 7.4567),
    (0.65, 271.30, 7.8930),
    (0.70, 279.55, 8.4717),
    (0.75, 262.07, 8.5236),
    (0.80, 277.45, 9.6953),
    (0.85, 284.50, 10.1700),
    (0.90, 241.75, 8.7012),
    (0.95, 269.95, 9.8716),
    (1.00, 259.57, 9.3502),
]
df = pd.DataFrame(data, columns=["Density", "Avg_Basis_Size", "Avg_Runtime_sec"])
# Density vs Lanczos Basis Size
fig1, ax1 = plt.subplots()
ax1.plot(df["Density"], df["Avg_Basis_Size"], marker='o')
ax1.set_xlabel("Density")
ax1.set_ylabel("Average Lanczos Basis Size")
ax1.set_title("Density vs. Average Lanczos Basis Size")
ax1.grid(True)
fig1.tight_layout()
# Density vs Runtime
fig2, ax2 = plt.subplots()
ax2.plot(df["Density"], df["Avg_Runtime_sec"], marker='o')
ax2.set_xlabel("Density")
ax2.set_ylabel("Average Runtime (s)")
ax2.set_title("Density vs. Average Runtime")
ax2.grid(True)
fig2.tight_layout()

plt.show()
