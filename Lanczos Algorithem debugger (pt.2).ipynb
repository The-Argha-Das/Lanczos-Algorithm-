# %%
import numpy as np
from scipy.sparse import random as sparse_random
from scipy.sparse.linalg import eigsh
import matplotlib.pyplot as plt

def generate_sparse_matrix(size, density):
    # Step 1: Assign distinct diagonal values (evenly spaced from -1 to 1)
    print(f"Generating sparse matrix with size {size} and density {density:.2%}")
    diagonal_values = np.linspace(-1, 1, size)
    print(f"Diagonal values (first 10): {diagonal_values[:10]}")

    # Step 2: Create random values for the off-diagonals
    print(f"Generating random off-diagonal values with density {density}")
    rvs = np.random.randn  
    upper = sparse_random(size, size, density=density/2, data_rvs=rvs, format='coo')
    matrix_s = upper + upper.T
    matrix_s.setdiag(diagonal_values)
    print(f"Matrix generated with shape {matrix_s.shape} and nnz (non-zero elements) {matrix_s.nnz}")
    
    return matrix_s.tocsr()  

def lanczos_algorithm(matrix_s, initial_vector, expected_eigenvalue, tol=1e-6, max_iter=10000):
    m = matrix_s.shape[0]
    print(f"Starting Lanczos algorithm with matrix size {m}, expected eigenvalue {expected_eigenvalue:.6f}, and tolerance {tol}")
    
    krylov_vectors = np.zeros((m, max_iter + 1))
    tridiag_matrix = np.zeros((max_iter + 1, max_iter))
    w = initial_vector / np.linalg.norm(initial_vector)
    krylov_vectors[:, 0] = w
    print(f"Initial vector normalized (first 10 elements): {w[:10]}")
    
    for k in range(max_iter):
        print(f"\n--- Iteration {k+1} ---")
        v = matrix_s.dot(krylov_vectors[:, k])
        tridiag_matrix[k, k] = np.dot(krylov_vectors[:, k].conj(), v)
        print(f"Tridiagonal matrix diagonal element at [{k}, {k}] = {tridiag_matrix[k, k]:.6f}")
        v = v - tridiag_matrix[k, k] * krylov_vectors[:, k]
        if k > 0:
            v = v - tridiag_matrix[k, k-1] * krylov_vectors[:, k-1]
        tridiag_matrix[k + 1, k] = np.linalg.norm(v)
        print(f"Tridiagonal matrix off-diagonal element at [{k+1}, {k}] = {tridiag_matrix[k + 1, k]:.6f}")
        if tridiag_matrix[k + 1, k] > tol:
            krylov_vectors[:, k + 1] = v / tridiag_matrix[k + 1, k]
        else:
            print(f"Convergence reached at iteration {k+1}, stopping Lanczos.")
            break
        
        eigenvalues = np.linalg.eigvalsh(tridiag_matrix[:k + 1, :k + 1])
        estimated_eigenvalue = eigenvalues[0]
        print(f"Estimated eigenvalue: {estimated_eigenvalue:.6f}")

        if abs(estimated_eigenvalue - expected_eigenvalue) < tol:
            print(f"Converged after {k+1} iterations with eigenvalue {estimated_eigenvalue:.6f}")
            return k + 1
        if estimated_eigenvalue<=expected_eigenvalue:
            print(f"Early stop after {k+1} iterations with eigenvalue {estimated_eigenvalue:.6f}")
            return k + 1
    return max_iter

def evaluate_average_iterations(size, density_levels, initial_vector, num_trials=2, tol=1e-6, max_iter=10000):
    avg_iterations_per_density = []
    
    for density in density_levels:
        print(f"\n--- Evaluating Density Level: {density:.2%} ---")
        total_iterations = 0
        
        for trial in range(num_trials):
            print(f"\nTrial {trial+1} for density level {density:.2%}")
            matrix_s = generate_sparse_matrix(size, density)
            exact_eigenvalue, _ = eigsh(matrix_s, k=1, which='SA', tol=tol)
            exact_eigenvalue = exact_eigenvalue[0]
            print(f"Exact smallest eigenvalue from eigsh: {exact_eigenvalue:.6f}")
            
            num_iterations = lanczos_algorithm(matrix_s, initial_vector, exact_eigenvalue, tol, max_iter)
            print(f"Number of iterations for trial {trial+1}: {num_iterations}")
            total_iterations += num_iterations
        
        avg_iterations = total_iterations / num_trials
        avg_iterations_per_density.append(avg_iterations)
        print(f"Density: {density:.2%}, Average Lanczos Basis Size: {avg_iterations}")
    
    return avg_iterations_per_density

# Parameters
size = 10000
density_levels = [0.01, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5, 0.55, 0.6, 0.65, 0.7, 0.75, 0.8, 0.85, 0.9, 0.95, 1.0]
initial_vector = np.random.rand(size)  # random initial vector

# Evaluate the basis size for different sparsity levels
average_basis_sizes = evaluate_average_iterations(size, density_levels, initial_vector, num_trials=2)

# Plot the results
plt.figure(figsize=(10, 6))
plt.plot(density_levels, average_basis_sizes, marker='o', linestyle='-', color='b')
plt.xlabel('Density Level (%)')
plt.ylabel('Average Lanczos Basis Size')
plt.title('Density vs Average Lanczos Basis Size')
plt.grid(True)
plt.show()
# Out:
# --- Evaluating Density Level: 1.00% ---
#
# Trial 1 for density level 1.00%
# Generating sparse matrix with size 10000 and density 1.00%
# Diagonal values (first 10): [-1.         -0.99979998 -0.99959996 -0.99939994 -0.99919992 -0.9989999
#  -0.99879988 -0.99859986 -0.99839984 -0.99819982]
# Generating random off-diagonal values with density 0.01
# Matrix generated with shape (10000, 10000) and nnz (non-zero elements) 1007384
# Exact smallest eigenvalue from eigsh: -20.345922
# Starting Lanczos algorithm with matrix size 10000, expected eigenvalue -20.345922, and tolerance 1e-06
# Initial vector normalized (first 10 elements): [0.01041762 0.01092008 0.0143442  0.00758388 0.01128866 0.00947694
#  0.01084838 0.01095722 0.01693382 0.00512332]
#
# --- Iteration 1 ---
# Tridiagonal matrix diagonal element at [0, 0] = 0.044103
# Tridiagonal matrix off-diagonal element at [1, 0] = 9.998282
# Estimated eigenvalue: 0.044103
#
# --- Iteration 2 ---
# Tridiagonal matrix diagonal element at [1, 1] = -0.109111
# Tridiagonal matrix off-diagonal element at [2, 1] = 10.181970
# Estimated eigenvalue: -10.031080
#
# --- Iteration 3 ---
# Tridiagonal matrix diagonal element at [2, 2] = 0.001277
# Tridiagonal matrix off-diagonal element at [3, 2] = 10.333835
# Estimated eigenvalue: -14.313757
#
# --- Iteration 4 ---
# Tridiagonal matrix diagonal element at [3, 3] = -0.282363
# Tridiagonal matrix off-diagonal element at [4, 3] = 10.255606
# Estimated eigenvalue: -16.537331
#
# --- Iteration 5 ---
# Tridiagonal matrix diagonal element at [4, 4] = 0.262337
# Tridiagonal matrix off-diagonal element at [5, 4] = 10.171630
# Estimated eigenvalue: -17.768407
#
# --- Iteration 6 ---
# Tridiagonal matrix diagonal element at [5, 5] = -0.059207
# Tridiagonal matrix off-diagonal element at [6, 5] = 10.335349
# Estimated eigenvalue: -18.478511
#
# --- Iteration 7 ---
# Tridiagonal matrix diagonal element at [6, 6] = -0.039809
# Tridiagonal matrix off-diagonal element at [7, 6] = 10.263176
# Estimated eigenvalue: -18.948999
#
# --- Iteration 8 ---
# Tridiagonal matrix diagonal element at [7, 7] = 0.194865
# Tridiagonal matrix off-diagonal element at [8, 7] = 10.258265
# Estimated eigenvalue: -19.273360
#
# --- Iteration 9 ---
# Tridiagonal matrix diagonal element at [8, 8] = -0.129925
# Tridiagonal matrix off-diagonal element at [9, 8] = 10.182616
# Estimated eigenvalue: -19.505380
#
# --- Iteration 10 ---
# Tridiagonal matrix diagonal element at [9, 9] = 0.115882
# Tridiagonal matrix off-diagonal element at [10, 9] = 10.002550
# Estimated eigenvalue: -19.673594
#
# --- Iteration 11 ---
# Tridiagonal matrix diagonal element at [10, 10] = -0.143347
# Tridiagonal matrix off-diagonal element at [11, 10] = 10.088819
# Estimated eigenvalue: -19.790808
#
# --- Iteration 12 ---
# Tridiagonal matrix diagonal element at [11, 11] = -0.133535
# Tridiagonal matrix off-diagonal element at [12, 11] = 10.182761
# Estimated eigenvalue: -19.875714
#
# --- Iteration 13 ---
# Tridiagonal matrix diagonal element at [12, 12] = 0.008230
# Tridiagonal matrix off-diagonal element at [13, 12] = 10.090895
# Estimated eigenvalue: -19.940720
#
# --- Iteration 14 ---
# Tridiagonal matrix diagonal element at [13, 13] = -0.221242
# Tridiagonal matrix off-diagonal element at [14, 13] = 10.030654
# Estimated eigenvalue: -19.991489
#
# --- Iteration 15 ---
# Tridiagonal matrix diagonal element at [14, 14] = -0.107321
# Tridiagonal matrix off-diagonal element at [15, 14] = 10.199828
# Estimated eigenvalue: -20.031377
#
# --- Iteration 16 ---
# Tridiagonal matrix diagonal element at [15, 15] = -0.183307
# Tridiagonal matrix off-diagonal element at [16, 15] = 10.338232
# Estimated eigenvalue: -20.064766
#
# --- Iteration 17 ---
# Tridiagonal matrix diagonal element at [16, 16] = 0.031330
# Tridiagonal matrix off-diagonal element at [17, 16] = 10.250299
# Estimated eigenvalue: -20.095278
#
# --- Iteration 18 ---
# Tridiagonal matrix diagonal element at [17, 17] = -0.010444
# Tridiagonal matrix off-diagonal element at [18, 17] = 10.087843
# Estimated eigenvalue: -20.123754
#
# --- Iteration 19 ---
# Tridiagonal matrix diagonal element at [18, 18] = -0.001748
# Tridiagonal matrix off-diagonal element at [19, 18] = 10.167722
# Estimated eigenvalue: -20.149136
#
# --- Iteration 20 ---
# Tridiagonal matrix diagonal element at [19, 19] = -0.097512
# Tridiagonal matrix off-diagonal element at [20, 19] = 10.168682
# Estimated eigenvalue: -20.171641
#
# --- Iteration 21 ---
# Tridiagonal matrix diagonal element at [20, 20] = -0.114852
# Tridiagonal matrix off-diagonal element at [21, 20] = 10.199232
# Estimated eigenvalue: -20.191728
#
# --- Iteration 22 ---
# Tridiagonal matrix diagonal element at [21, 21] = -0.404074
# Tridiagonal matrix off-diagonal element at [22, 21] = 10.248866
# Estimated eigenvalue: -20.210508
#
# --- Iteration 23 ---
# Tridiagonal matrix diagonal element at [22, 22] = 0.043010
# Tridiagonal matrix off-diagonal element at [23, 22] = 10.117423
# Estimated eigenvalue: -20.228843
#
# --- Iteration 24 ---
# Tridiagonal matrix diagonal element at [23, 23] = 0.180018
# Tridiagonal matrix off-diagonal element at [24, 23] = 10.232570
# Estimated eigenvalue: -20.245527
#
# --- Iteration 25 ---
# Tridiagonal matrix diagonal element at [24, 24] = 0.115947
# Tridiagonal matrix off-diagonal element at [25, 24] = 10.255086
# Estimated eigenvalue: -20.260284
#
# --- Iteration 26 ---
# Tridiagonal matrix diagonal element at [25, 25] = -0.051432
# Tridiagonal matrix off-diagonal element at [26, 25] = 10.107074
# Estimated eigenvalue: -20.273436
#
# --- Iteration 27 ---
# Tridiagonal matrix diagonal element at [26, 26] = 0.213887
# Tridiagonal matrix off-diagonal element at [27, 26] = 10.207776
# Estimated eigenvalue: -20.284539
#
# --- Iteration 28 ---
# Tridiagonal matrix diagonal element at [27, 27] = -0.084894
# Tridiagonal matrix off-diagonal element at [28, 27] = 10.144072
# Estimated eigenvalue: -20.293889
#
# --- Iteration 29 ---
# Tridiagonal matrix diagonal element at [28, 28] = -0.067247
# Tridiagonal matrix off-diagonal element at [29, 28] = 10.217799
# Estimated eigenvalue: -20.301790
#
# --- Iteration 30 ---
# Tridiagonal matrix diagonal element at [29, 29] = 0.051283
# Tridiagonal matrix off-diagonal element at [30, 29] = 10.141388
# Estimated eigenvalue: -20.308599
#
# --- Iteration 31 ---
# Tridiagonal matrix diagonal element at [30, 30] = -0.189733
# Tridiagonal matrix off-diagonal element at [31, 30] = 10.140156
# Estimated eigenvalue: -20.314474
#
# --- Iteration 32 ---
# Tridiagonal matrix diagonal element at [31, 31] = 0.228322
# Tridiagonal matrix off-diagonal element at [32, 31] = 10.108495
# Estimated eigenvalue: -20.319471
#
# --- Iteration 33 ---
# Tridiagonal matrix diagonal element at [32, 32] = 0.006267
# Tridiagonal matrix off-diagonal element at [33, 32] = 10.240385
# Estimated eigenvalue: -20.323555
#
# --- Iteration 34 ---
# Tridiagonal matrix diagonal element at [33, 33] = 0.050559
# Tridiagonal matrix off-diagonal element at [34, 33] = 10.113599
# Estimated eigenvalue: -20.327000
#
# --- Iteration 35 ---
# Tridiagonal matrix diagonal element at [34, 34] = -0.068262
# Tridiagonal matrix off-diagonal element at [35, 34] = 10.257031
# Estimated eigenvalue: -20.329871
#
# --- Iteration 36 ---
# Tridiagonal matrix diagonal element at [35, 35] = -0.042010
# Tridiagonal matrix off-diagonal element at [36, 35] = 10.218865
# Estimated eigenvalue: -20.332391
#
# --- Iteration 37 ---
# Tridiagonal matrix diagonal element at [36, 36] = 0.084291
# Tridiagonal matrix off-diagonal element at [37, 36] = 10.268492
# Estimated eigenvalue: -20.334639
#
# --- Iteration 38 ---
# Tridiagonal matrix diagonal element at [37, 37] = 0.073070
# Tridiagonal matrix off-diagonal element at [38, 37] = 10.100676
# Estimated eigenvalue: -20.336691
#
# --- Iteration 39 ---
# Tridiagonal matrix diagonal element at [38, 38] = 0.064148
# Tridiagonal matrix off-diagonal element at [39, 38] = 10.078158
# Estimated eigenvalue: -20.338490
#
# --- Iteration 40 ---
# Tridiagonal matrix diagonal element at [39, 39] = 0.077239
# Tridiagonal matrix off-diagonal element at [40, 39] = 10.104439
# Estimated eigenvalue: -20.340000
#
# --- Iteration 41 ---
# Tridiagonal matrix diagonal element at [40, 40] = -0.007617
# Tridiagonal matrix off-diagonal element at [41, 40] = 10.074561
# Estimated eigenvalue: -20.341240
#
# --- Iteration 42 ---
# Tridiagonal matrix diagonal element at [41, 41] = 0.268754
# Tridiagonal matrix off-diagonal element at [42, 41] = 10.084447
# Estimated eigenvalue: -20.342217
#
# --- Iteration 43 ---
# Tridiagonal matrix diagonal element at [42, 42] = 0.332681
# Tridiagonal matrix off-diagonal element at [43, 42] = 10.228254
# Estimated eigenvalue: -20.342941
#
# --- Iteration 44 ---
# Tridiagonal matrix diagonal element at [43, 43] = 0.242384
# Tridiagonal matrix off-diagonal element at [44, 43] = 10.075447
# Estimated eigenvalue: -20.343483
#
# --- Iteration 45 ---
# Tridiagonal matrix diagonal element at [44, 44] = 0.177651
# Tridiagonal matrix off-diagonal element at [45, 44] = 10.154178
# Estimated eigenvalue: -20.343874
#
# --- Iteration 46 ---
# Tridiagonal matrix diagonal element at [45, 45] = -0.147233
# Tridiagonal matrix off-diagonal element at [46, 45] = 10.254642
# Estimated eigenvalue: -20.344168
#
# --- Iteration 47 ---
# Tridiagonal matrix diagonal element at [46, 46] = -0.111874
# Tridiagonal matrix off-diagonal element at [47, 46] = 10.162335
# Estimated eigenvalue: -20.344408
#
# --- Iteration 48 ---
# Tridiagonal matrix diagonal element at [47, 47] = -0.039344
# Tridiagonal matrix off-diagonal element at [48, 47] = 10.326252
# Estimated eigenvalue: -20.344610
#
# --- Iteration 49 ---
# Tridiagonal matrix diagonal element at [48, 48] = -0.146431
# Tridiagonal matrix off-diagonal element at [49, 48] = 10.044507
# Estimated eigenvalue: -20.344795
#
# --- Iteration 50 ---
# Tridiagonal matrix diagonal element at [49, 49] = -0.099382
# Tridiagonal matrix off-diagonal element at [50, 49] = 10.293780
# Estimated eigenvalue: -20.344962
#
# --- Iteration 51 ---
# Tridiagonal matrix diagonal element at [50, 50] = 0.272155
# Tridiagonal matrix off-diagonal element at [51, 50] = 10.105618
# Estimated eigenvalue: -20.345117
#
# --- Iteration 52 ---
# Tridiagonal matrix diagonal element at [51, 51] = 0.004767
# Tridiagonal matrix off-diagonal element at [52, 51] = 10.056130
# Estimated eigenvalue: -20.345254
#
# --- Iteration 53 ---
# Tridiagonal matrix diagonal element at [52, 52] = 0.079426
# Tridiagonal matrix off-diagonal element at [53, 52] = 9.996762
# Estimated eigenvalue: -20.345370
#
# --- Iteration 54 ---
# Tridiagonal matrix diagonal element at [53, 53] = -0.031736
# Tridiagonal matrix off-diagonal element at [54, 53] = 10.140180
# Estimated eigenvalue: -20.345463
#
# --- Iteration 55 ---
# Tridiagonal matrix diagonal element at [54, 54] = -0.137921
# Tridiagonal matrix off-diagonal element at [55, 54] = 10.050131
# Estimated eigenvalue: -20.345540
#
# --- Iteration 56 ---
# Tridiagonal matrix diagonal element at [55, 55] = 0.058281
# Tridiagonal matrix off-diagonal element at [56, 55] = 10.062261
# Estimated eigenvalue: -20.345602
#
# --- Iteration 57 ---
# Tridiagonal matrix diagonal element at [56, 56] = 0.033949
# Tridiagonal matrix off-diagonal element at [57, 56] = 10.260641
# Estimated eigenvalue: -20.345650
#
# --- Iteration 58 ---
# Tridiagonal matrix diagonal element at [57, 57] = -0.038768
# Tridiagonal matrix off-diagonal element at [58, 57] = 10.109024
# Estimated eigenvalue: -20.345690
#
# --- Iteration 59 ---
# Tridiagonal matrix diagonal element at [58, 58] = 0.027078
# Tridiagonal matrix off-diagonal element at [59, 58] = 10.152800
# Estimated eigenvalue: -20.345723
#
# --- Iteration 60 ---
# Tridiagonal matrix diagonal element at [59, 59] = -0.096973
# Tridiagonal matrix off-diagonal element at [60, 59] = 10.251964
# Estimated eigenvalue: -20.345751
#
# --- Iteration 61 ---
# Tridiagonal matrix diagonal element at [60, 60] = -0.101768
# Tridiagonal matrix off-diagonal element at [61, 60] = 10.154022
# Estimated eigenvalue: -20.345776
#
# --- Iteration 62 ---
# Tridiagonal matrix diagonal element at [61, 61] = 0.236318
# Tridiagonal matrix off-diagonal element at [62, 61] = 10.183688
# Estimated eigenvalue: -20.345798
#
# --- Iteration 63 ---
# Tridiagonal matrix diagonal element at [62, 62] = 0.160394
# Tridiagonal matrix off-diagonal element at [63, 62] = 10.063494
# Estimated eigenvalue: -20.345817
#
# --- Iteration 64 ---
# Tridiagonal matrix diagonal element at [63, 63] = -0.072182
# Tridiagonal matrix off-diagonal element at [64, 63] = 10.089966
# Estimated eigenvalue: -20.345832
#
# --- Iteration 65 ---
# Tridiagonal matrix diagonal element at [64, 64] = 0.088016
# Tridiagonal matrix off-diagonal element at [65, 64] = 10.035725
# Estimated eigenvalue: -20.345845
#
# --- Iteration 66 ---
# Tridiagonal matrix diagonal element at [65, 65] = -0.175049
# Tridiagonal matrix off-diagonal element at [66, 65] = 10.231777
# Estimated eigenvalue: -20.345855
#
# --- Iteration 67 ---
# Tridiagonal matrix diagonal element at [66, 66] = -0.008131
# Tridiagonal matrix off-diagonal element at [67, 66] = 10.177661
# Estimated eigenvalue: -20.345863
#
# --- Iteration 68 ---
# Tridiagonal matrix diagonal element at [67, 67] = -0.001305
# Tridiagonal matrix off-diagonal element at [68, 67] = 10.100154
# Estimated eigenvalue: -20.345871
#
# --- Iteration 69 ---
# Tridiagonal matrix diagonal element at [68, 68] = -0.080866
# Tridiagonal matrix off-diagonal element at [69, 68] = 10.119051
# Estimated eigenvalue: -20.345877
#
# --- Iteration 70 ---
# Tridiagonal matrix diagonal element at [69, 69] = -0.038707
# Tridiagonal matrix off-diagonal element at [70, 69] = 10.167093
# Estimated eigenvalue: -20.345882
#
# --- Iteration 71 ---
# Tridiagonal matrix diagonal element at [70, 70] = 0.057134
# Tridiagonal matrix off-diagonal element at [71, 70] = 10.079704
# Estimated eigenvalue: -20.345887
#
# --- Iteration 72 ---
# Tridiagonal matrix diagonal element at [71, 71] = -0.304556
# Tridiagonal matrix off-diagonal element at [72, 71] = 10.124720
# Estimated eigenvalue: -20.345891
#
# --- Iteration 73 ---
# Tridiagonal matrix diagonal element at [72, 72] = 0.188887
# Tridiagonal matrix off-diagonal element at [73, 72] = 10.127394
# Estimated eigenvalue: -20.345894
#
# --- Iteration 74 ---
# Tridiagonal matrix diagonal element at [73, 73] = 0.003191
# Tridiagonal matrix off-diagonal element at [74, 73] = 10.105006
# Estimated eigenvalue: -20.345897
#
# --- Iteration 75 ---
# Tridiagonal matrix diagonal element at [74, 74] = -0.077257
# Tridiagonal matrix off-diagonal element at [75, 74] = 10.215542
# Estimated eigenvalue: -20.345900
#
# --- Iteration 76 ---
# Tridiagonal matrix diagonal element at [75, 75] = 0.015270
# Tridiagonal matrix off-diagonal element at [76, 75] = 10.238646
# Estimated eigenvalue: -20.345902
#
# --- Iteration 77 ---
# Tridiagonal matrix diagonal element at [76, 76] = 0.104412
# Tridiagonal matrix off-diagonal element at [77, 76] = 10.181035
# Estimated eigenvalue: -20.345904
#
# --- Iteration 78 ---
# Tridiagonal matrix diagonal element at [77, 77] = -0.076056
# Tridiagonal matrix off-diagonal element at [78, 77] = 10.226273
# Estimated eigenvalue: -20.345905
#
# --- Iteration 79 ---
# Tridiagonal matrix diagonal element at [78, 78] = 0.180619
# Tridiagonal matrix off-diagonal element at [79, 78] = 10.185006
# Estimated eigenvalue: -20.345907
#
# --- Iteration 80 ---
# Tridiagonal matrix diagonal element at [79, 79] = 0.053890
# Tridiagonal matrix off-diagonal element at [80, 79] = 10.186102
# Estimated eigenvalue: -20.345908
#
# --- Iteration 81 ---
# Tridiagonal matrix diagonal element at [80, 80] = -0.186908
# Tridiagonal matrix off-diagonal element at [81, 80] = 10.172995
# Estimated eigenvalue: -20.345910
#
# --- Iteration 82 ---
# Tridiagonal matrix diagonal element at [81, 81] = -0.041561
# Tridiagonal matrix off-diagonal element at [82, 81] = 10.019219
# Estimated eigenvalue: -20.345911
#
# --- Iteration 83 ---
# Tridiagonal matrix diagonal element at [82, 82] = 0.044653
# Tridiagonal matrix off-diagonal element at [83, 82] = 10.211826
# Estimated eigenvalue: -20.345912
#
# --- Iteration 84 ---
# Tridiagonal matrix diagonal element at [83, 83] = 0.170586
# Tridiagonal matrix off-diagonal element at [84, 83] = 10.148131
# Estimated eigenvalue: -20.345913
#
# --- Iteration 85 ---
# Tridiagonal matrix diagonal element at [84, 84] = -0.058561
# Tridiagonal matrix off-diagonal element at [85, 84] = 10.160866
# Estimated eigenvalue: -20.345914
#
# --- Iteration 86 ---
# Tridiagonal matrix diagonal element at [85, 85] = -0.002593
# Tridiagonal matrix off-diagonal element at [86, 85] = 10.148884
# Estimated eigenvalue: -20.345914
#
# --- Iteration 87 ---
# Tridiagonal matrix diagonal element at [86, 86] = -0.182525
# Tridiagonal matrix off-diagonal element at [87, 86] = 10.268305
# Estimated eigenvalue: -20.345915
#
# --- Iteration 88 ---
# Tridiagonal matrix diagonal element at [87, 87] = 0.110187
# Tridiagonal matrix off-diagonal element at [88, 87] = 10.095791
# Estimated eigenvalue: -20.345916
#
# --- Iteration 89 ---
# Tridiagonal matrix diagonal element at [88, 88] = -0.193735
# Tridiagonal matrix off-diagonal element at [89, 88] = 10.109264
# Estimated eigenvalue: -20.345916
#
# --- Iteration 90 ---
# Tridiagonal matrix diagonal element at [89, 89] = 0.151278
# Tridiagonal matrix off-diagonal element at [90, 89] = 10.182466
# Estimated eigenvalue: -20.345917
#
# --- Iteration 91 ---
# Tridiagonal matrix diagonal element at [90, 90] = -0.015396
# Tridiagonal matrix off-diagonal element at [91, 90] = 10.159810
# Estimated eigenvalue: -20.345917
#
# --- Iteration 92 ---
# Tridiagonal matrix diagonal element at [91, 91] = 0.031268
# Tridiagonal matrix off-diagonal element at [92, 91] = 10.059073
# Estimated eigenvalue: -20.345918
#
# --- Iteration 93 ---
# Tridiagonal matrix diagonal element at [92, 92] = -0.045207
# Tridiagonal matrix off-diagonal element at [93, 92] = 10.232665
# Estimated eigenvalue: -20.345918
#
# --- Iteration 94 ---
# Tridiagonal matrix diagonal element at [93, 93] = -0.183972
# Tridiagonal matrix off-diagonal element at [94, 93] = 10.131411
# Estimated eigenvalue: -20.345918
#
# --- Iteration 95 ---
# Tridiagonal matrix diagonal element at [94, 94] = 0.128036
# Tridiagonal matrix off-diagonal element at [95, 94] = 10.201809
# Estimated eigenvalue: -20.345919
#
# --- Iteration 96 ---
# Tridiagonal matrix diagonal element at [95, 95] = -0.304558
# Tridiagonal matrix off-diagonal element at [96, 95] = 10.116598
# Estimated eigenvalue: -20.345919
#
# --- Iteration 97 ---
# Tridiagonal matrix diagonal element at [96, 96] = -0.036219
# Tridiagonal matrix off-diagonal element at [97, 96] = 10.176405
# Estimated eigenvalue: -20.345919
#
# --- Iteration 98 ---
# Tridiagonal matrix diagonal element at [97, 97] = -0.033243
# Tridiagonal matrix off-diagonal element at [98, 97] = 10.136550
# Estimated eigenvalue: -20.345920
#
# --- Iteration 99 ---
# Tridiagonal matrix diagonal element at [98, 98] = 0.099524
# Tridiagonal matrix off-diagonal element at [99, 98] = 10.127481
# Estimated eigenvalue: -20.345920
#
# --- Iteration 100 ---
# Tridiagonal matrix diagonal element at [99, 99] = -0.371360
# Tridiagonal matrix off-diagonal element at [100, 99] = 10.264363
# Estimated eigenvalue: -20.345920
#
# --- Iteration 101 ---
# Tridiagonal matrix diagonal element at [100, 100] = 0.419770
# Tridiagonal matrix off-diagonal element at [101, 100] = 10.018294
# Estimated eigenvalue: -20.345920
#
# --- Iteration 102 ---
# Tridiagonal matrix diagonal element at [101, 101] = -0.195070
# Tridiagonal matrix off-diagonal element at [102, 101] = 10.191805
# Estimated eigenvalue: -20.345921
#
# --- Iteration 103 ---
# Tridiagonal matrix diagonal element at [102, 102] = 0.381386
# Tridiagonal matrix off-diagonal element at [103, 102] = 10.090519
# Estimated eigenvalue: -20.345921
# Converged after 103 iterations with eigenvalue -20.345921
# Number of iterations for trial 1: 103
#
# Trial 2 for density level 1.00%
# Generating sparse matrix with size 10000 and density 1.00%
# Diagonal values (first 10): [-1.         -0.99979998 -0.99959996 -0.99939994 -0.99919992 -0.9989999
#  -0.99879988 -0.99859986 -0.99839984 -0.99819982]
# Generating random off-diagonal values with density 0.01
# Matrix generated with shape (10000, 10000) and nnz (non-zero elements) 1007496
# Exact smallest eigenvalue from eigsh: -20.335267
# Starting Lanczos algorithm with matrix size 10000, expected eigenvalue -20.335267, and tolerance 1e-06
# Initial vector normalized (first 10 elements): [0.01041762 0.01092008 0.0143442  0.00758388 0.01128866 0.00947694
#  0.01084838 0.01095722 0.01693382 0.00512332]
#
# --- Iteration 1 ---
# Tridiagonal matrix diagonal element at [0, 0] = -0.180054
# Tridiagonal matrix off-diagonal element at [1, 0] = 10.048886
# Estimated eigenvalue: -0.180054
#
# --- Iteration 2 ---
# Tridiagonal matrix diagonal element at [1, 1] = 0.098417
# Tridiagonal matrix off-diagonal element at [2, 1] = 10.162757
# Estimated eigenvalue: -10.090669
#
# --- Iteration 3 ---
# Tridiagonal matrix diagonal element at [2, 2] = -0.041306
# Tridiagonal matrix off-diagonal element at [3, 2] = 10.230342
# Estimated eigenvalue: -14.298308
#
# --- Iteration 4 ---
# Tridiagonal matrix diagonal element at [3, 3] = 0.253139
# Tridiagonal matrix off-diagonal element at [4, 3] = 9.958364
# Estimated eigenvalue: -16.392665
#
# --- Iteration 5 ---
# Tridiagonal matrix diagonal element at [4, 4] = 0.133244
# Tridiagonal matrix off-diagonal element at [5, 4] = 10.187945
# Estimated eigenvalue: -17.481789
#
# --- Iteration 6 ---
# Tridiagonal matrix diagonal element at [5, 5] = 0.075055
# Tridiagonal matrix off-diagonal element at [6, 5] = 10.048185
# Estimated eigenvalue: -18.153703
#
# --- Iteration 7 ---
# Tridiagonal matrix diagonal element at [6, 6] = 0.170261
# Tridiagonal matrix off-diagonal element at [7, 6] = 10.142810
# Estimated eigenvalue: -18.591110
#
# --- Iteration 8 ---
# Tridiagonal matrix diagonal element at [7, 7] = -0.202909
# Tridiagonal matrix off-diagonal element at [8, 7] = 10.169417
# Estimated eigenvalue: -18.904134
#
# --- Iteration 9 ---
# Tridiagonal matrix diagonal element at [8, 8] = -0.234738
# Tridiagonal matrix off-diagonal element at [9, 8] = 10.199817
# Estimated eigenvalue: -19.151782
#
# --- Iteration 10 ---
# Tridiagonal matrix diagonal element at [9, 9] = -0.227434
# Tridiagonal matrix off-diagonal element at [10, 9] = 10.166803
# Estimated eigenvalue: -19.360225
#
# --- Iteration 11 ---
# Tridiagonal matrix diagonal element at [10, 10] = -0.120217
# Tridiagonal matrix off-diagonal element at [11, 10] = 10.187447
# Estimated eigenvalue: -19.535721
#
# --- Iteration 12 ---
# Tridiagonal matrix diagonal element at [11, 11] = -0.108263
# Tridiagonal matrix off-diagonal element at [12, 11] = 10.105243
# Estimated eigenvalue: -19.681191
#
# --- Iteration 13 ---
# Tridiagonal matrix diagonal element at [12, 12] = 0.081173
# Tridiagonal matrix off-diagonal element at [13, 12] = 10.127199
# Estimated eigenvalue: -19.795057
#
# --- Iteration 14 ---
# Tridiagonal matrix diagonal element at [13, 13] = -0.255489
# Tridiagonal matrix off-diagonal element at [14, 13] = 10.076435
# Estimated eigenvalue: -19.883341
#
# --- Iteration 15 ---
# Tridiagonal matrix diagonal element at [14, 14] = 0.045165
# Tridiagonal matrix off-diagonal element at [15, 14] = 10.214524
# Estimated eigenvalue: -19.951162
#
# --- Iteration 16 ---
# Tridiagonal matrix diagonal element at [15, 15] = -0.135136
# Tridiagonal matrix off-diagonal element at [16, 15] = 10.109398
# Estimated eigenvalue: -20.005356
#
# --- Iteration 17 ---
# Tridiagonal matrix diagonal element at [16, 16] = 0.060258
# Tridiagonal matrix off-diagonal element at [17, 16] = 10.129249
# Estimated eigenvalue: -20.048501
#
# --- Iteration 18 ---
# Tridiagonal matrix diagonal element at [17, 17] = 0.035046
# Tridiagonal matrix off-diagonal element at [18, 17] = 10.081741
# Estimated eigenvalue: -20.082592
#
# --- Iteration 19 ---
# Tridiagonal matrix diagonal element at [18, 18] = -0.014123
# Tridiagonal matrix off-diagonal element at [19, 18] = 10.195213
# Estimated eigenvalue: -20.109220
#
# --- Iteration 20 ---
# Tridiagonal matrix diagonal element at [19, 19] = -0.063710
# Tridiagonal matrix off-diagonal element at [20, 19] = 10.162055
# Estimated eigenvalue: -20.130955
#
# --- Iteration 21 ---
# Tridiagonal matrix diagonal element at [20, 20] = 0.051140
# Tridiagonal matrix off-diagonal element at [21, 20] = 10.032609
# Estimated eigenvalue: -20.149046
#
# --- Iteration 22 ---
# Tridiagonal matrix diagonal element at [21, 21] = 0.005071
# Tridiagonal matrix off-diagonal element at [22, 21] = 10.182351
# Estimated eigenvalue: -20.163573
#
# --- Iteration 23 ---
# Tridiagonal matrix diagonal element at [22, 22] = 0.020804
# Tridiagonal matrix off-diagonal element at [23, 22] = 10.235831
# Estimated eigenvalue: -20.175590
#
# --- Iteration 24 ---
# Tridiagonal matrix diagonal element at [23, 23] = -0.263982
# Tridiagonal matrix off-diagonal element at [24, 23] = 10.227382
# Estimated eigenvalue: -20.186249
#
# --- Iteration 25 ---
# Tridiagonal matrix diagonal element at [24, 24] = -0.012045
# Tridiagonal matrix off-diagonal element at [25, 24] = 10.007541
# Estimated eigenvalue: -20.196290
#
# --- Iteration 26 ---
# Tridiagonal matrix diagonal element at [25, 25] = -0.249401
# Tridiagonal matrix off-diagonal element at [26, 25] = 10.098288
# Estimated eigenvalue: -20.205442
#
# --- Iteration 27 ---
# Tridiagonal matrix diagonal element at [26, 26] = 0.064951
# Tridiagonal matrix off-diagonal element at [27, 26] = 10.140735
# Estimated eigenvalue: -20.213746
#
# --- Iteration 28 ---
# Tridiagonal matrix diagonal element at [27, 27] = -0.150376
# Tridiagonal matrix off-diagonal element at [28, 27] = 10.133067
# Estimated eigenvalue: -20.221295
#
# --- Iteration 29 ---
# Tridiagonal matrix diagonal element at [28, 28] = -0.079144
# Tridiagonal matrix off-diagonal element at [29, 28] = 10.170997
# Estimated eigenvalue: -20.228240
#
# --- Iteration 30 ---
# Tridiagonal matrix diagonal element at [29, 29] = -0.038829
# Tridiagonal matrix off-diagonal element at [30, 29] = 10.158581
# Estimated eigenvalue: -20.234721
#
# --- Iteration 31 ---
# Tridiagonal matrix diagonal element at [30, 30] = 0.181248
# Tridiagonal matrix off-diagonal element at [31, 30] = 10.048897
# Estimated eigenvalue: -20.240667
#
# --- Iteration 32 ---
# Tridiagonal matrix diagonal element at [31, 31] = -0.269230
# Tridiagonal matrix off-diagonal element at [32, 31] = 10.171732
# Estimated eigenvalue: -20.245937
#
# --- Iteration 33 ---
# Tridiagonal matrix diagonal element at [32, 32] = 0.099522
# Tridiagonal matrix off-diagonal element at [33, 32] = 10.219965
# Estimated eigenvalue: -20.250719
#
# --- Iteration 34 ---
# Tridiagonal matrix diagonal element at [33, 33] = 0.047985
# Tridiagonal matrix off-diagonal element at [34, 33] = 10.165023
# Estimated eigenvalue: -20.255100
#
# --- Iteration 35 ---
# Tridiagonal matrix diagonal element at [34, 34] = -0.186836
# Tridiagonal matrix off-diagonal element at [35, 34] = 10.155309
# Estimated eigenvalue: -20.259177
#
# --- Iteration 36 ---
# Tridiagonal matrix diagonal element at [35, 35] = 0.036996
# Tridiagonal matrix off-diagonal element at [36, 35] = 10.235625
# Estimated eigenvalue: -20.263015
#
# --- Iteration 37 ---
# Tridiagonal matrix diagonal element at [36, 36] = -0.137613
# Tridiagonal matrix off-diagonal element at [37, 36] = 10.167727
# Estimated eigenvalue: -20.266762
#
# --- Iteration 38 ---
# Tridiagonal matrix diagonal element at [37, 37] = -0.327628
# Tridiagonal matrix off-diagonal element at [38, 37] = 10.236797
# Estimated eigenvalue: -20.270584
#
# --- Iteration 39 ---
# Tridiagonal matrix diagonal element at [38, 38] = -0.109993
# Tridiagonal matrix off-diagonal element at [39, 38] = 10.178557
# Estimated eigenvalue: -20.274751
#
# --- Iteration 40 ---
# Tridiagonal matrix diagonal element at [39, 39] = 0.044580
# Tridiagonal matrix off-diagonal element at [40, 39] = 10.226196
# Estimated eigenvalue: -20.279309
#
# --- Iteration 41 ---
# Tridiagonal matrix diagonal element at [40, 40] = 0.057509
# Tridiagonal matrix off-diagonal element at [41, 40] = 10.238237
# Estimated eigenvalue: -20.284291
#
# --- Iteration 42 ---
# Tridiagonal matrix diagonal element at [41, 41] = -0.181198
# Tridiagonal matrix off-diagonal element at [42, 41] = 10.121586
# Estimated eigenvalue: -20.289850
#
# --- Iteration 43 ---
# Tridiagonal matrix diagonal element at [42, 42] = 0.125056
# Tridiagonal matrix off-diagonal element at [43, 42] = 10.197479
# Estimated eigenvalue: -20.295804
#
# --- Iteration 44 ---
# Tridiagonal matrix diagonal element at [43, 43] = 0.248113
# Tridiagonal matrix off-diagonal element at [44, 43] = 10.190152
# Estimated eigenvalue: -20.301803
#
# --- Iteration 45 ---
# Tridiagonal matrix diagonal element at [44, 44] = 0.089923
# Tridiagonal matrix off-diagonal element at [45, 44] = 10.178720
# Estimated eigenvalue: -20.307495
#
# --- Iteration 46 ---
# Tridiagonal matrix diagonal element at [45, 45] = 0.247936
# Tridiagonal matrix off-diagonal element at [46, 45] = 10.148190
# Estimated eigenvalue: -20.312599
#
# --- Iteration 47 ---
# Tridiagonal matrix diagonal element at [46, 46] = -0.094422
# Tridiagonal matrix off-diagonal element at [47, 46] = 10.065309
# Estimated eigenvalue: -20.317003
#
# --- Iteration 48 ---
# Tridiagonal matrix diagonal element at [47, 47] = -0.067311
# Tridiagonal matrix off-diagonal element at [48, 47] = 10.097633
# Estimated eigenvalue: -20.320693
#
# --- Iteration 49 ---
# Tridiagonal matrix diagonal element at [48, 48] = -0.119843
# Tridiagonal matrix off-diagonal element at [49, 48] = 10.071229
# Estimated eigenvalue: -20.323768
#
# --- Iteration 50 ---
# Tridiagonal matrix diagonal element at [49, 49] = 0.038906
# Tridiagonal matrix off-diagonal element at [50, 49] = 10.076795
# Estimated eigenvalue: -20.326276
#
# --- Iteration 51 ---
# Tridiagonal matrix diagonal element at [50, 50] = 0.179090
# Tridiagonal matrix off-diagonal element at [51, 50] = 10.021825
# Estimated eigenvalue: -20.328244
#
# --- Iteration 52 ---
# Tridiagonal matrix diagonal element at [51, 51] = 0.025109
# Tridiagonal matrix off-diagonal element at [52, 51] = 10.246420
# Estimated eigenvalue: -20.329717
#
# --- Iteration 53 ---
# Tridiagonal matrix diagonal element at [52, 52] = 0.060304
# Tridiagonal matrix off-diagonal element at [53, 52] = 10.140319
# Estimated eigenvalue: -20.330882
#
# --- Iteration 54 ---
# Tridiagonal matrix diagonal element at [53, 53] = 0.096505
# Tridiagonal matrix off-diagonal element at [54, 53] = 10.007774
# Estimated eigenvalue: -20.331801
#
# --- Iteration 55 ---
# Tridiagonal matrix diagonal element at [54, 54] = 0.100682
# Tridiagonal matrix off-diagonal element at [55, 54] = 10.113493
# Estimated eigenvalue: -20.332492
#
# --- Iteration 56 ---
# Tridiagonal matrix diagonal element at [55, 55] = 0.147704
# Tridiagonal matrix off-diagonal element at [56, 55] = 10.199202
# Estimated eigenvalue: -20.333009
#
# --- Iteration 57 ---
# Tridiagonal matrix diagonal element at [56, 56] = -0.169079
# Tridiagonal matrix off-diagonal element at [57, 56] = 10.110518
# Estimated eigenvalue: -20.333414
#
# --- Iteration 58 ---
# Tridiagonal matrix diagonal element at [57, 57] = 0.180158
# Tridiagonal matrix off-diagonal element at [58, 57] = 10.124685
# Estimated eigenvalue: -20.333734
#
# --- Iteration 59 ---
# Tridiagonal matrix diagonal element at [58, 58] = 0.101775
# Tridiagonal matrix off-diagonal element at [59, 58] = 10.198836
# Estimated eigenvalue: -20.333982
#
# --- Iteration 60 ---
# Tridiagonal matrix diagonal element at [59, 59] = 0.022808
# Tridiagonal matrix off-diagonal element at [60, 59] = 10.074301
# Estimated eigenvalue: -20.334181
#
# --- Iteration 61 ---
# Tridiagonal matrix diagonal element at [60, 60] = -0.094419
# Tridiagonal matrix off-diagonal element at [61, 60] = 10.140351
# Estimated eigenvalue: -20.334339
#
# --- Iteration 62 ---
# Tridiagonal matrix diagonal element at [61, 61] = -0.123469
# Tridiagonal matrix off-diagonal element at [62, 61] = 10.188988
# Estimated eigenvalue: -20.334469
#
# --- Iteration 63 ---
# Tridiagonal matrix diagonal element at [62, 62] = 0.085076
# Tridiagonal matrix off-diagonal element at [63, 62] = 10.102204
# Estimated eigenvalue: -20.334579
#
# --- Iteration 64 ---
# Tridiagonal matrix diagonal element at [63, 63] = -0.291289
# Tridiagonal matrix off-diagonal element at [64, 63] = 10.186652
# Estimated eigenvalue: -20.334673
#
# --- Iteration 65 ---
# Tridiagonal matrix diagonal element at [64, 64] = 0.000421
# Tridiagonal matrix off-diagonal element at [65, 64] = 10.219958
# Estimated eigenvalue: -20.334756
#
# --- Iteration 66 ---
# Tridiagonal matrix diagonal element at [65, 65] = 0.189407
# Tridiagonal matrix off-diagonal element at [66, 65] = 10.102333
# Estimated eigenvalue: -20.334832
#
# --- Iteration 67 ---
# Tridiagonal matrix diagonal element at [66, 66] = 0.028757
# Tridiagonal matrix off-diagonal element at [67, 66] = 10.091579
# Estimated eigenvalue: -20.334897
#
# --- Iteration 68 ---
# Tridiagonal matrix diagonal element at [67, 67] = 0.172292
# Tridiagonal matrix off-diagonal element at [68, 67] = 10.202379
# Estimated eigenvalue: -20.334951
#
# --- Iteration 69 ---
# Tridiagonal matrix diagonal element at [68, 68] = 0.070295
# Tridiagonal matrix off-diagonal element at [69, 68] = 10.167854
# Estimated eigenvalue: -20.334997
#
# --- Iteration 70 ---
# Tridiagonal matrix diagonal element at [69, 69] = -0.205219
# Tridiagonal matrix off-diagonal element at [70, 69] = 10.204147
# Estimated eigenvalue: -20.335036
#
# --- Iteration 71 ---
# Tridiagonal matrix diagonal element at [70, 70] = 0.063589
# Tridiagonal matrix off-diagonal element at [71, 70] = 10.134529
# Estimated eigenvalue: -20.335071
#
# --- Iteration 72 ---
# Tridiagonal matrix diagonal element at [71, 71] = -0.118683
# Tridiagonal matrix off-diagonal element at [72, 71] = 10.028456
# Estimated eigenvalue: -20.335103
#
# --- Iteration 73 ---
# Tridiagonal matrix diagonal element at [72, 72] = 0.180376
# Tridiagonal matrix off-diagonal element at [73, 72] = 10.287993
# Estimated eigenvalue: -20.335129
#
# --- Iteration 74 ---
# Tridiagonal matrix diagonal element at [73, 73] = 0.068976
# Tridiagonal matrix off-diagonal element at [74, 73] = 10.100901
# Estimated eigenvalue: -20.335152
#
# --- Iteration 75 ---
# Tridiagonal matrix diagonal element at [74, 74] = 0.077738
# Tridiagonal matrix off-diagonal element at [75, 74] = 10.034093
# Estimated eigenvalue: -20.335172
#
# --- Iteration 76 ---
# Tridiagonal matrix diagonal element at [75, 75] = -0.045279
# Tridiagonal matrix off-diagonal element at [76, 75] = 10.109461
# Estimated eigenvalue: -20.335189
#
# --- Iteration 77 ---
# Tridiagonal matrix diagonal element at [76, 76] = -0.164408
# Tridiagonal matrix off-diagonal element at [77, 76] = 10.100190
# Estimated eigenvalue: -20.335202
#
# --- Iteration 78 ---
# Tridiagonal matrix diagonal element at [77, 77] = 0.004285
# Tridiagonal matrix off-diagonal element at [78, 77] = 10.153505
# Estimated eigenvalue: -20.335213
#
# --- Iteration 79 ---
# Tridiagonal matrix diagonal element at [78, 78] = -0.130261
# Tridiagonal matrix off-diagonal element at [79, 78] = 10.116907
# Estimated eigenvalue: -20.335223
#
# --- Iteration 80 ---
# Tridiagonal matrix diagonal element at [79, 79] = -0.013336
# Tridiagonal matrix off-diagonal element at [80, 79] = 10.094976
# Estimated eigenvalue: -20.335231
#
# --- Iteration 81 ---
# Tridiagonal matrix diagonal element at [80, 80] = -0.033794
# Tridiagonal matrix off-diagonal element at [81, 80] = 10.053387
# Estimated eigenvalue: -20.335238
#
# --- Iteration 82 ---
# Tridiagonal matrix diagonal element at [81, 81] = 0.074224
# Tridiagonal matrix off-diagonal element at [82, 81] = 10.035433
# Estimated eigenvalue: -20.335244
#
# --- Iteration 83 ---
# Tridiagonal matrix diagonal element at [82, 82] = -0.117911
# Tridiagonal matrix off-diagonal element at [83, 82] = 10.033481
# Estimated eigenvalue: -20.335249
#
# --- Iteration 84 ---
# Tridiagonal matrix diagonal element at [83, 83] = -0.048471
# Tridiagonal matrix off-diagonal element at [84, 83] = 10.102763
# Estimated eigenvalue: -20.335253
#
# --- Iteration 85 ---
# Tridiagonal matrix diagonal element at [84, 84] = 0.065721
# Tridiagonal matrix off-diagonal element at [85, 84] = 10.099187
# Estimated eigenvalue: -20.335255
#
# --- Iteration 86 ---
# Tridiagonal matrix diagonal element at [85, 85] = -0.018667
# Tridiagonal matrix off-diagonal element at [86, 85] = 10.219803
# Estimated eigenvalue: -20.335258
#
# --- Iteration 87 ---
# Tridiagonal matrix diagonal element at [86, 86] = -0.056891
# Tridiagonal matrix off-diagonal element at [87, 86] = 10.107312
# Estimated eigenvalue: -20.335260
#
# --- Iteration 88 ---
# Tridiagonal matrix diagonal element at [87, 87] = 0.224065
# Tridiagonal matrix off-diagonal element at [88, 87] = 10.097026
# Estimated eigenvalue: -20.335261
#
# --- Iteration 89 ---
# Tridiagonal matrix diagonal element at [88, 88] = 0.032243
# Tridiagonal matrix off-diagonal element at [89, 88] = 10.158226
# Estimated eigenvalue: -20.335262
#
# --- Iteration 90 ---
# Tridiagonal matrix diagonal element at [89, 89] = 0.028276
# Tridiagonal matrix off-diagonal element at [90, 89] = 10.065582
# Estimated eigenvalue: -20.335263
#
# --- Iteration 91 ---
# Tridiagonal matrix diagonal element at [90, 90] = 0.234717
# Tridiagonal matrix off-diagonal element at [91, 90] = 10.139803
# Estimated eigenvalue: -20.335264
#
# --- Iteration 92 ---
# Tridiagonal matrix diagonal element at [91, 91] = 0.252733
# Tridiagonal matrix off-diagonal element at [92, 91] = 10.226540
# Estimated eigenvalue: -20.335265
#
# --- Iteration 93 ---
# Tridiagonal matrix diagonal element at [92, 92] = 0.006973
# Tridiagonal matrix off-diagonal element at [93, 92] = 10.100653
# Estimated eigenvalue: -20.335265
#
# --- Iteration 94 ---
# Tridiagonal matrix diagonal element at [93, 93] = 0.010846
# Tridiagonal matrix off-diagonal element at [94, 93] = 10.104967
# Estimated eigenvalue: -20.335265
#
# --- Iteration 95 ---
# Tridiagonal matrix diagonal element at [94, 94] = -0.032103
# Tridiagonal matrix off-diagonal element at [95, 94] = 10.160440
# Estimated eigenvalue: -20.335266
#
# --- Iteration 96 ---
# Tridiagonal matrix diagonal element at [95, 95] = 0.148818
# Tridiagonal matrix off-diagonal element at [96, 95] = 10.139925
# Estimated eigenvalue: -20.335266
# Converged after 96 iterations with eigenvalue -20.335266
# Number of iterations for trial 2: 96
# Density: 1.00%, Average Lanczos Basis Size: 99.5
#
# --- Evaluating Density Level: 5.00% ---
#
# Trial 1 for density level 5.00%
# Generating sparse matrix with size 10000 and density 5.00%
# Diagonal values (first 10): [-1.         -0.99979998 -0.99959996 -0.99939994 -0.99919992 -0.9989999
#  -0.99879988 -0.99859986 -0.99839984 -0.99819982]
# Generating random off-diagonal values with density 0.05
# Matrix generated with shape (10000, 10000) and nnz (non-zero elements) 4946886
# Exact smallest eigenvalue from eigsh: -44.772356
# Starting Lanczos algorithm with matrix size 10000, expected eigenvalue -44.772356, and tolerance 1e-06
# Initial vector normalized (first 10 elements): [0.01041762 0.01092008 0.0143442  0.00758388 0.01128866 0.00947694
#  0.01084838 0.01095722 0.01693382 0.00512332]
#
# --- Iteration 1 ---
# Tridiagonal matrix diagonal element at [0, 0] = -0.095058
# Tridiagonal matrix off-diagonal element at [1, 0] = 22.391847
# Estimated eigenvalue: -0.095058
#
# --- Iteration 2 ---
# Tridiagonal matrix diagonal element at [1, 1] = 0.441007
# Tridiagonal matrix off-diagonal element at [2, 1] = 22.488801
# Estimated eigenvalue: -22.220477
#
# --- Iteration 3 ---
# Tridiagonal matrix diagonal element at [2, 2] = -0.078180
# Tridiagonal matrix off-diagonal element at [3, 2] = 22.470756
# Estimated eigenvalue: -31.559370
#
# --- Iteration 4 ---
# Tridiagonal matrix diagonal element at [3, 3] = -0.389291
# Tridiagonal matrix off-diagonal element at [4, 3] = 22.482354
# Estimated eigenvalue: -36.274902
#
# --- Iteration 5 ---
# Tridiagonal matrix diagonal element at [4, 4] = 0.044850
# Tridiagonal matrix off-diagonal element at [5, 4] = 22.609603
# Estimated eigenvalue: -38.932474
#
# --- Iteration 6 ---
# Tridiagonal matrix diagonal element at [5, 5] = 0.432275
# Tridiagonal matrix off-diagonal element at [6, 5] = 22.394420
# Estimated eigenvalue: -40.542410
#
# --- Iteration 7 ---
# Tridiagonal matrix diagonal element at [6, 6] = -0.268351
# Tridiagonal matrix off-diagonal element at [7, 6] = 22.496791
# Estimated eigenvalue: -41.567158
#
# --- Iteration 8 ---
# Tridiagonal matrix diagonal element at [7, 7] = -0.288460
# Tridiagonal matrix off-diagonal element at [8, 7] = 22.336233
# Estimated eigenvalue: -42.280732
#
# --- Iteration 9 ---
# Tridiagonal matrix diagonal element at [8, 8] = 0.091642
# Tridiagonal matrix off-diagonal element at [9, 8] = 22.343138
# Estimated eigenvalue: -42.788607
#
# --- Iteration 10 ---
# Tridiagonal matrix diagonal element at [9, 9] = 0.144584
# Tridiagonal matrix off-diagonal element at [10, 9] = 22.062827
# Estimated eigenvalue: -43.152218
#
# --- Iteration 11 ---
# Tridiagonal matrix diagonal element at [10, 10] = 0.142520
# Tridiagonal matrix off-diagonal element at [11, 10] = 22.257801
# Estimated eigenvalue: -43.405429
#
# --- Iteration 12 ---
# Tridiagonal matrix diagonal element at [11, 11] = 0.183688
# Tridiagonal matrix off-diagonal element at [12, 11] = 22.339891
# Estimated eigenvalue: -43.586236
#
# --- Iteration 13 ---
# Tridiagonal matrix diagonal element at [12, 12] = -0.027275
# Tridiagonal matrix off-diagonal element at [13, 12] = 22.370734
# Estimated eigenvalue: -43.721617
#
# --- Iteration 14 ---
# Tridiagonal matrix diagonal element at [13, 13] = 0.231167
# Tridiagonal matrix off-diagonal element at [14, 13] = 22.327250
# Estimated eigenvalue: -43.827336
#
# --- Iteration 15 ---
# Tridiagonal matrix diagonal element at [14, 14] = -0.253864
# Tridiagonal matrix off-diagonal element at [15, 14] = 22.457015
# Estimated eigenvalue: -43.912883
#
# --- Iteration 16 ---
# Tridiagonal matrix diagonal element at [15, 15] = 0.107065
# Tridiagonal matrix off-diagonal element at [16, 15] = 22.432218
# Estimated eigenvalue: -43.985936
#
# --- Iteration 17 ---
# Tridiagonal matrix diagonal element at [16, 16] = 0.103589
# Tridiagonal matrix off-diagonal element at [17, 16] = 22.818209
# Estimated eigenvalue: -44.049745
#
# --- Iteration 18 ---
# Tridiagonal matrix diagonal element at [17, 17] = 0.236536
# Tridiagonal matrix off-diagonal element at [18, 17] = 22.674238
# Estimated eigenvalue: -44.109795
#
# --- Iteration 19 ---
# Tridiagonal matrix diagonal element at [18, 18] = 0.291710
# Tridiagonal matrix off-diagonal element at [19, 18] = 22.443309
# Estimated eigenvalue: -44.167873
#
# --- Iteration 20 ---
# Tridiagonal matrix diagonal element at [19, 19] = -0.098383
# Tridiagonal matrix off-diagonal element at [20, 19] = 22.655209
# Estimated eigenvalue: -44.223538
#
# --- Iteration 21 ---
# Tridiagonal matrix diagonal element at [20, 20] = 0.574869
# Tridiagonal matrix off-diagonal element at [21, 20] = 22.302695
# Estimated eigenvalue: -44.277326
#
# --- Iteration 22 ---
# Tridiagonal matrix diagonal element at [21, 21] = 0.774187
# Tridiagonal matrix off-diagonal element at [22, 21] = 22.356515
# Estimated eigenvalue: -44.324630
#
# --- Iteration 23 ---
# Tridiagonal matrix diagonal element at [22, 22] = 0.160148
# Tridiagonal matrix off-diagonal element at [23, 22] = 22.270159
# Estimated eigenvalue: -44.364101
#
# --- Iteration 24 ---
# Tridiagonal matrix diagonal element at [23, 23] = 0.082533
# Tridiagonal matrix off-diagonal element at [24, 23] = 22.674166
# Estimated eigenvalue: -44.396318
#
# --- Iteration 25 ---
# Tridiagonal matrix diagonal element at [24, 24] = -0.331074
# Tridiagonal matrix off-diagonal element at [25, 24] = 22.303595
# Estimated eigenvalue: -44.424655
#
# --- Iteration 26 ---
# Tridiagonal matrix diagonal element at [25, 25] = -0.637219
# Tridiagonal matrix off-diagonal element at [26, 25] = 22.278089
# Estimated eigenvalue: -44.450452
#
# --- Iteration 27 ---
# Tridiagonal matrix diagonal element at [26, 26] = 0.011082
# Tridiagonal matrix off-diagonal element at [27, 26] = 22.567247
# Estimated eigenvalue: -44.474194
#
# --- Iteration 28 ---
# Tridiagonal matrix diagonal element at [27, 27] = 0.175922
# Tridiagonal matrix off-diagonal element at [28, 27] = 22.405863
# Estimated eigenvalue: -44.496545
#
# --- Iteration 29 ---
# Tridiagonal matrix diagonal element at [28, 28] = -0.407805
# Tridiagonal matrix off-diagonal element at [29, 28] = 22.596869
# Estimated eigenvalue: -44.517787
#
# --- Iteration 30 ---
# Tridiagonal matrix diagonal element at [29, 29] = -0.015830
# Tridiagonal matrix off-diagonal element at [30, 29] = 22.289536
# Estimated eigenvalue: -44.538973
#
# --- Iteration 31 ---
# Tridiagonal matrix diagonal element at [30, 30] = 0.034124
# Tridiagonal matrix off-diagonal element at [31, 30] = 22.303468
# Estimated eigenvalue: -44.559457
#
# --- Iteration 32 ---
# Tridiagonal matrix diagonal element at [31, 31] = 0.132912
# Tridiagonal matrix off-diagonal element at [32, 31] = 22.329032
# Estimated eigenvalue: -44.578556
#
# --- Iteration 33 ---
# Tridiagonal matrix diagonal element at [32, 32] = -0.149760
# Tridiagonal matrix off-diagonal element at [33, 32] = 22.404754
# Estimated eigenvalue: -44.595987
#
# --- Iteration 34 ---
# Tridiagonal matrix diagonal element at [33, 33] = -0.252824
# Tridiagonal matrix off-diagonal element at [34, 33] = 22.485106
# Estimated eigenvalue: -44.612076
#
# --- Iteration 35 ---
# Tridiagonal matrix diagonal element at [34, 34] = -0.259720
# Tridiagonal matrix off-diagonal element at [35, 34] = 22.300828
# Estimated eigenvalue: -44.627376
#
# --- Iteration 36 ---
# Tridiagonal matrix diagonal element at [35, 35] = 0.478800
# Tridiagonal matrix off-diagonal element at [36, 35] = 22.641868
# Estimated eigenvalue: -44.641412
#
# --- Iteration 37 ---
# Tridiagonal matrix diagonal element at [36, 36] = 0.343721
# Tridiagonal matrix off-diagonal element at [37, 36] = 22.467929
# Estimated eigenvalue: -44.654289
#
# --- Iteration 38 ---
# Tridiagonal matrix diagonal element at [37, 37] = -0.134635
# Tridiagonal matrix off-diagonal element at [38, 37] = 22.648691
# Estimated eigenvalue: -44.666071
#
# --- Iteration 39 ---
# Tridiagonal matrix diagonal element at [38, 38] = 0.045791
# Tridiagonal matrix off-diagonal element at [39, 38] = 22.316888
# Estimated eigenvalue: -44.677314
#
# --- Iteration 40 ---
# Tridiagonal matrix diagonal element at [39, 39] = -0.310820
# Tridiagonal matrix off-diagonal element at [40, 39] = 22.222624
# Estimated eigenvalue: -44.687928
#
# --- Iteration 41 ---
# Tridiagonal matrix diagonal element at [40, 40] = -0.234734
# Tridiagonal matrix off-diagonal element at [41, 40] = 22.086780
# Estimated eigenvalue: -44.697803
#
# --- Iteration 42 ---
# Tridiagonal matrix diagonal element at [41, 41] = -0.032474
# Tridiagonal matrix off-diagonal element at [42, 41] = 22.295285
# Estimated eigenvalue: -44.706554
#
# --- Iteration 43 ---
# Tridiagonal matrix diagonal element at [42, 42] = 0.406859
# Tridiagonal matrix off-diagonal element at [43, 42] = 22.461735
# Estimated eigenvalue: -44.714056
#
# --- Iteration 44 ---
# Tridiagonal matrix diagonal element at [43, 43] = -0.656530
# Tridiagonal matrix off-diagonal element at [44, 43] = 22.212804
# Estimated eigenvalue: -44.720664
#
# --- Iteration 45 ---
# Tridiagonal matrix diagonal element at [44, 44] = 0.308491
# Tridiagonal matrix off-diagonal element at [45, 44] = 22.161996
# Estimated eigenvalue: -44.726410
#
# --- Iteration 46 ---
# Tridiagonal matrix diagonal element at [45, 45] = 0.241772
# Tridiagonal matrix off-diagonal element at [46, 45] = 22.262006
# Estimated eigenvalue: -44.731136
#
# --- Iteration 47 ---
# Tridiagonal matrix diagonal element at [46, 46] = -0.016441
# Tridiagonal matrix off-diagonal element at [47, 46] = 22.327060
# Estimated eigenvalue: -44.734964
#
# --- Iteration 48 ---
# Tridiagonal matrix diagonal element at [47, 47] = 0.131745
# Tridiagonal matrix off-diagonal element at [48, 47] = 22.413966
# Estimated eigenvalue: -44.738076
#
# --- Iteration 49 ---
# Tridiagonal matrix diagonal element at [48, 48] = -0.078600
# Tridiagonal matrix off-diagonal element at [49, 48] = 22.360460
# Estimated eigenvalue: -44.740659
#
# --- Iteration 50 ---
# Tridiagonal matrix diagonal element at [49, 49] = -0.186135
# Tridiagonal matrix off-diagonal element at [50, 49] = 22.603575
# Estimated eigenvalue: -44.742851
#
# --- Iteration 51 ---
# Tridiagonal matrix diagonal element at [50, 50] = 0.086542
# Tridiagonal matrix off-diagonal element at [51, 50] = 22.639869
# Estimated eigenvalue: -44.744810
#
# --- Iteration 52 ---
# Tridiagonal matrix diagonal element at [51, 51] = -0.142425
# Tridiagonal matrix off-diagonal element at [52, 51] = 22.622950
# Estimated eigenvalue: -44.746655
#
# --- Iteration 53 ---
# Tridiagonal matrix diagonal element at [52, 52] = 0.027510
# Tridiagonal matrix off-diagonal element at [53, 52] = 22.607772
# Estimated eigenvalue: -44.748474
#
# --- Iteration 54 ---
# Tridiagonal matrix diagonal element at [53, 53] = -0.198422
# Tridiagonal matrix off-diagonal element at [54, 53] = 22.331195
# Estimated eigenvalue: -44.750355
#
# --- Iteration 55 ---
# Tridiagonal matrix diagonal element at [54, 54] = 0.376065
# Tridiagonal matrix off-diagonal element at [55, 54] = 22.477537
# Estimated eigenvalue: -44.752261
#
# --- Iteration 56 ---
# Tridiagonal matrix diagonal element at [55, 55] = 0.249365
# Tridiagonal matrix off-diagonal element at [56, 55] = 22.121849
# Estimated eigenvalue: -44.754165
#
# --- Iteration 57 ---
# Tridiagonal matrix diagonal element at [56, 56] = 0.609825
# Tridiagonal matrix off-diagonal element at [57, 56] = 22.470764
# Estimated eigenvalue: -44.755908
#
# --- Iteration 58 ---
# ...
#
# --- Iteration 86 ---
# Tridiagonal matrix diagonal element at [85, 85] = 1.861575
# Tridiagonal matrix off-diagonal element at [86, 85] = 79.391137
# Estimated eigenvalue: -161.229524
#
# --- Iteration 87 ---
# Tridiagonal matrix diagonal element at [86, 86] = -0.785114
# Tridiagonal matrix off-diagonal element at [87, 86] = 79.241388
# Estimated eigenvalue: -161.229602
#
# --- Iteration 88 ---
# Tridiagonal matrix diagonal element at [87, 87] = 0.392812
# Tridiagonal matrix off-diagonal element at [88, 87] = 80.243669
# Estimated eigenvalue: -161.229661
#
# --- Iteration 89 ---
# Tridiagonal matrix diagonal element at [88, 88] = 1.447206
# Tridiagonal matrix off-diagonal element at [89, 88] = 80.626421
# Estimated eigenvalue: -161.229707
#
# --- Iteration 90 ---
# Tridiagonal matrix diagonal element at [89, 89] = -0.662166
# Tridiagonal matrix off-diagonal element at [90, 89] = 80.296897
# Estimated eigenvalue: -161.229743
#
# --- Iteration 91 ---
# Tridiagonal matrix diagonal element at [90, 90] = -0.407958
# Tridiagonal matrix off-diagonal element at [91, 90] = 80.938884
# Estimated eigenvalue: -161.229772
#
# --- Iteration 92 ---
# Tridiagonal matrix diagonal element at [91, 91] = 1.555490
# Tridiagonal matrix off-diagonal element at [92, 91] = 79.769797
# Estimated eigenvalue: -161.229796
#
# --- Iteration 93 ---
# Tridiagonal matrix diagonal element at [92, 92] = 2.666317
# Tridiagonal matrix off-diagonal element at [93, 92] = 80.338754
# Estimated eigenvalue: -161.229814
#
# --- Iteration 94 ---
# Tridiagonal matrix diagonal element at [93, 93] = -0.684502
# Tridiagonal matrix off-diagonal element at [94, 93] = 80.398483
# Estimated eigenvalue: -161.229828
#
# --- Iteration 95 ---
# Tridiagonal matrix diagonal element at [94, 94] = 0.040821
# Tridiagonal matrix off-diagonal element at [95, 94] = 80.789534
# Estimated eigenvalue: -161.229839
#
# --- Iteration 96 ---
# Tridiagonal matrix diagonal element at [95, 95] = 0.528897
# Tridiagonal matrix off-diagonal element at [96, 95] = 80.010623
# Estimated eigenvalue: -161.229848
#
# --- Iteration 97 ---
# Tridiagonal matrix diagonal element at [96, 96] = -0.090983
# Tridiagonal matrix off-diagonal element at [97, 96] = 80.911729
# Estimated eigenvalue: -161.229855
#
# --- Iteration 98 ---
# Tridiagonal matrix diagonal element at [97, 97] = -0.611929
# Tridiagonal matrix off-diagonal element at [98, 97] = 80.156409
# Estimated eigenvalue: -161.229861
#
# --- Iteration 99 ---
# Tridiagonal matrix diagonal element at [98, 98] = -0.711215
# Tridiagonal matrix off-diagonal element at [99, 98] = 80.743689
# Estimated eigenvalue: -161.229866
#
# --- Iteration 100 ---
# Tridiagonal matrix diagonal element at [99, 99] = 2.159773
# Tridiagonal matrix off-diagonal element at [100, 99] = 80.792783
# Estimated eigenvalue: -161.229870
#
# --- Iteration 101 ---
# Tridiagonal matrix diagonal element at [100, 100] = 1.109876
# Tridiagonal matrix off-diagonal element at [101, 100] = 80.591464
# Estimated eigenvalue: -161.229874
#
# --- Iteration 102 ---
# Tridiagonal matrix diagonal element at [101, 101] = 0.136484
# Tridiagonal matrix off-diagonal element at [102, 101] = 81.218332
# Estimated eigenvalue: -161.229877
#
# --- Iteration 103 ---
# Tridiagonal matrix diagonal element at [102, 102] = 1.533139
# Tridiagonal matrix off-diagonal element at [103, 102] = 80.609200
# Estimated eigenvalue: -161.229879
#
# --- Iteration 104 ---
# Tridiagonal matrix diagonal element at [103, 103] = 0.827439
# Tridiagonal matrix off-diagonal element at [104, 103] = 79.664893
# Estimated eigenvalue: -161.229881
#
# --- Iteration 105 ---
# Tridiagonal matrix diagonal element at [104, 104] = 0.432467
# Tridiagonal matrix off-diagonal element at [105, 104] = 80.062542
# Estimated eigenvalue: -161.229883
#
# --- Iteration 106 ---
# Tridiagonal matrix diagonal element at [105, 105] = -0.731169
# Tridiagonal matrix off-diagonal element at [106, 105] = 80.070347
# Estimated eigenvalue: -161.229884
#
# --- Iteration 107 ---
# Tridiagonal matrix diagonal element at [106, 106] = -0.002870
# Tridiagonal matrix off-diagonal element at [107, 106] = 80.896884
# Estimated eigenvalue: -161.229885
#
# --- Iteration 108 ---
# Tridiagonal matrix diagonal element at [107, 107] = 1.871956
# Tridiagonal matrix off-diagonal element at [108, 107] = 79.584728
# Estimated eigenvalue: -161.229886
#
# --- Iteration 109 ---
# Tridiagonal matrix diagonal element at [108, 108] = 0.124365
# Tridiagonal matrix off-diagonal element at [109, 108] = 81.170272
# Estimated eigenvalue: -161.229887
#
# --- Iteration 110 ---
# Tridiagonal matrix diagonal element at [109, 109] = -0.259452
# Tridiagonal matrix off-diagonal element at [110, 109] = 80.606027
# Estimated eigenvalue: -161.229888
#
# --- Iteration 111 ---
# Tridiagonal matrix diagonal element at [110, 110] = 1.709083
# Tridiagonal matrix off-diagonal element at [111, 110] = 80.416010
# Estimated eigenvalue: -161.229888
#
# --- Iteration 112 ---
# Tridiagonal matrix diagonal element at [111, 111] = 1.668886
# Tridiagonal matrix off-diagonal element at [112, 111] = 80.084105
# Estimated eigenvalue: -161.229889
#
# --- Iteration 113 ---
# Tridiagonal matrix diagonal element at [112, 112] = 1.557344
# Tridiagonal matrix off-diagonal element at [113, 112] = 79.989964
# Estimated eigenvalue: -161.229889
#
# --- Iteration 114 ---
# Tridiagonal matrix diagonal element at [113, 113] = 1.263836
# Tridiagonal matrix off-diagonal element at [114, 113] = 81.242480
# Estimated eigenvalue: -161.229889
#
# --- Iteration 115 ---
# Tridiagonal matrix diagonal element at [114, 114] = 0.643938
# Tridiagonal matrix off-diagonal element at [115, 114] = 80.040759
# Estimated eigenvalue: -161.229889
#
# --- Iteration 116 ---
# Tridiagonal matrix diagonal element at [115, 115] = 0.935244
# Tridiagonal matrix off-diagonal element at [116, 115] = 81.330060
# Estimated eigenvalue: -161.229889
#
# --- Iteration 117 ---
# Tridiagonal matrix diagonal element at [116, 116] = -1.166440
# Tridiagonal matrix off-diagonal element at [117, 116] = 80.908975
# Estimated eigenvalue: -161.229889
#
# --- Iteration 118 ---
# Tridiagonal matrix diagonal element at [117, 117] = -0.068416
# Tridiagonal matrix off-diagonal element at [118, 117] = 81.073745
# Estimated eigenvalue: -161.229890
#
# --- Iteration 119 ---
# Tridiagonal matrix diagonal element at [118, 118] = -0.016447
# Tridiagonal matrix off-diagonal element at [119, 118] = 80.202039
# Estimated eigenvalue: -161.229890
#
# --- Iteration 120 ---
# Tridiagonal matrix diagonal element at [119, 119] = -1.317483
# Tridiagonal matrix off-diagonal element at [120, 119] = 81.214787
# Estimated eigenvalue: -161.229890
#
# --- Iteration 121 ---
# Tridiagonal matrix diagonal element at [120, 120] = 0.703963
# Tridiagonal matrix off-diagonal element at [121, 120] = 80.047087
# Estimated eigenvalue: -161.229890
#
# --- Iteration 122 ---
# Tridiagonal matrix diagonal element at [121, 121] = -2.878427
# Tridiagonal matrix off-diagonal element at [122, 121] = 81.447326
# Estimated eigenvalue: -161.229890
#
# --- Iteration 123 ---
# Tridiagonal matrix diagonal element at [122, 122] = -2.028310
# Tridiagonal matrix off-diagonal element at [123, 122] = 81.605347
# Estimated eigenvalue: -161.229890
#
# --- Iteration 124 ---
# Tridiagonal matrix diagonal element at [123, 123] = -0.152145
# Tridiagonal matrix off-diagonal element at [124, 123] = 79.517928
# Estimated eigenvalue: -161.229890
#
# --- Iteration 125 ---
# Tridiagonal matrix diagonal element at [124, 124] = 1.778395
# Tridiagonal matrix off-diagonal element at [125, 124] = 79.864693
# Estimated eigenvalue: -161.229890
#
# --- Iteration 126 ---
# Tridiagonal matrix diagonal element at [125, 125] = -1.873903
# Tridiagonal matrix off-diagonal element at [126, 125] = 80.190921
# Estimated eigenvalue: -161.229890
#
# --- Iteration 127 ---
# Tridiagonal matrix diagonal element at [126, 126] = 0.825251
# Tridiagonal matrix off-diagonal element at [127, 126] = 81.288365
# Estimated eigenvalue: -161.229890
#
# --- Iteration 128 ---
# Tridiagonal matrix diagonal element at [127, 127] = 1.663624
# Tridiagonal matrix off-diagonal element at [128, 127] = 80.830548
# Estimated eigenvalue: -161.229890
#
# --- Iteration 129 ---
# Tridiagonal matrix diagonal element at [128, 128] = -0.547976
# Tridiagonal matrix off-diagonal element at [129, 128] = 79.663110
# Estimated eigenvalue: -161.229890
#
# --- Iteration 130 ---
# Tridiagonal matrix diagonal element at [129, 129] = 1.208772
# Tridiagonal matrix off-diagonal element at [130, 129] = 79.768575
# Estimated eigenvalue: -161.229890
#
# --- Iteration 131 ---
# Tridiagonal matrix diagonal element at [130, 130] = -0.118917
# Tridiagonal matrix off-diagonal element at [131, 130] = 80.859477
# Estimated eigenvalue: -161.229890
#
# --- Iteration 132 ---
# Tridiagonal matrix diagonal element at [131, 131] = 0.497762
# Tridiagonal matrix off-diagonal element at [132, 131] = 81.137992
# Estimated eigenvalue: -161.229891
#
# --- Iteration 133 ---
# Tridiagonal matrix diagonal element at [132, 132] = -2.740414
# Tridiagonal matrix off-diagonal element at [133, 132] = 81.074665
# Estimated eigenvalue: -161.229891
#
# --- Iteration 134 ---
# Tridiagonal matrix diagonal element at [133, 133] = -0.233898
# Tridiagonal matrix off-diagonal element at [134, 133] = 80.824892
# Estimated eigenvalue: -161.229891
#
# --- Iteration 135 ---
# Tridiagonal matrix diagonal element at [134, 134] = -0.717681
# Tridiagonal matrix off-diagonal element at [135, 134] = 80.650953
# Estimated eigenvalue: -161.229891
#
# --- Iteration 136 ---
# Tridiagonal matrix diagonal element at [135, 135] = 0.881746
# Tridiagonal matrix off-diagonal element at [136, 135] = 81.928149
# Estimated eigenvalue: -161.229891
#
# --- Iteration 137 ---
# Tridiagonal matrix diagonal element at [136, 136] = 0.190878
# Tridiagonal matrix off-diagonal element at [137, 136] = 80.850779
# Estimated eigenvalue: -161.229891
#
# --- Iteration 138 ---
# Tridiagonal matrix diagonal element at [137, 137] = -0.817907
# Tridiagonal matrix off-diagonal element at [138, 137] = 80.178257
# Estimated eigenvalue: -161.229891
#
# --- Iteration 139 ---
# Tridiagonal matrix diagonal element at [138, 138] = -0.351440
# Tridiagonal matrix off-diagonal element at [139, 138] = 80.172793
# Estimated eigenvalue: -161.229891
#
# --- Iteration 140 ---
# Tridiagonal matrix diagonal element at [139, 139] = 0.600436
# Tridiagonal matrix off-diagonal element at [140, 139] = 80.768442
# Estimated eigenvalue: -161.229891
#
# --- Iteration 141 ---
# Tridiagonal matrix diagonal element at [140, 140] = 0.034331
# Tridiagonal matrix off-diagonal element at [141, 140] = 81.148468
# Estimated eigenvalue: -161.229891
#
# --- Iteration 142 ---
# Tridiagonal matrix diagonal element at [141, 141] = 0.296215
# Tridiagonal matrix off-diagonal element at [142, 141] = 79.717154
# Estimated eigenvalue: -161.229891
#
# --- Iteration 143 ---
# Tridiagonal matrix diagonal element at [142, 142] = -0.545417
# Tridiagonal matrix off-diagonal element at [143, 142] = 80.731490
# Estimated eigenvalue: -161.229891
#
# --- Iteration 144 ---
# Tridiagonal matrix diagonal element at [143, 143] = 0.359324
# Tridiagonal matrix off-diagonal element at [144, 143] = 80.350163
# Estimated eigenvalue: -161.229892
#
# --- Iteration 145 ---
# Tridiagonal matrix diagonal element at [144, 144] = -1.880894
# Tridiagonal matrix off-diagonal element at [145, 144] = 80.610705
# Estimated eigenvalue: -161.229892
#
# --- Iteration 146 ---
# Tridiagonal matrix diagonal element at [145, 145] = 0.784522
# Tridiagonal matrix off-diagonal element at [146, 145] = 80.170779
# Estimated eigenvalue: -161.229892
#
# --- Iteration 147 ---
# Tridiagonal matrix diagonal element at [146, 146] = -0.052644
# Tridiagonal matrix off-diagonal element at [147, 146] = 80.331604
# Estimated eigenvalue: -161.229892
#
# --- Iteration 148 ---
# Tridiagonal matrix diagonal element at [147, 147] = -1.558867
# Tridiagonal matrix off-diagonal element at [148, 147] = 81.784838
# Estimated eigenvalue: -161.229893
#
# --- Iteration 149 ---
# Tridiagonal matrix diagonal element at [148, 148] = 0.758221
# Tridiagonal matrix off-diagonal element at [149, 148] = 80.020398
# Estimated eigenvalue: -161.229893
#
# --- Iteration 150 ---
# Tridiagonal matrix diagonal element at [149, 149] = -1.004646
# Tridiagonal matrix off-diagonal element at [150, 149] = 80.057050
# Estimated eigenvalue: -161.229893
#
# --- Iteration 151 ---
# Tridiagonal matrix diagonal element at [150, 150] = 2.441588
# Tridiagonal matrix off-diagonal element at [151, 150] = 81.022649
# Estimated eigenvalue: -161.229894
#
# --- Iteration 152 ---
# Tridiagonal matrix diagonal element at [151, 151] = 0.331615
# Tridiagonal matrix off-diagonal element at [152, 151] = 80.050774
# Estimated eigenvalue: -161.229895
#
# --- Iteration 153 ---
# Tridiagonal matrix diagonal element at [152, 152] = 1.604527
# Tridiagonal matrix off-diagonal element at [153, 152] = 80.584022
# Estimated eigenvalue: -161.229896
#
# --- Iteration 154 ---
# Tridiagonal matrix diagonal element at [153, 153] = 0.351053
# Tridiagonal matrix off-diagonal element at [154, 153] = 80.783008
# Estimated eigenvalue: -161.229897
#
# --- Iteration 155 ---
# Tridiagonal matrix diagonal element at [154, 154] = -1.391915
# Tridiagonal matrix off-diagonal element at [155, 154] = 79.731542
# Estimated eigenvalue: -161.229898
#
# --- Iteration 156 ---
# Tridiagonal matrix diagonal element at [155, 155] = 1.306715
# Tridiagonal matrix off-diagonal element at [156, 155] = 80.680400
# Estimated eigenvalue: -161.229901
#
# --- Iteration 157 ---
# Tridiagonal matrix diagonal element at [156, 156] = 0.254956
# Tridiagonal matrix off-diagonal element at [157, 156] = 81.082934
# Estimated eigenvalue: -161.229903
#
# --- Iteration 158 ---
# Tridiagonal matrix diagonal element at [157, 157] = 2.277348
# Tridiagonal matrix off-diagonal element at [158, 157] = 80.460490
# Estimated eigenvalue: -161.229907
#
# --- Iteration 159 ---
# Tridiagonal matrix diagonal element at [158, 158] = -0.218153
# Tridiagonal matrix off-diagonal element at [159, 158] = 79.906058
# Estimated eigenvalue: -161.229913
#
# --- Iteration 160 ---
# Tridiagonal matrix diagonal element at [159, 159] = -1.926595
# Tridiagonal matrix off-diagonal element at [160, 159] = 79.789345
# Estimated eigenvalue: -161.229922
#
# --- Iteration 161 ---
# Tridiagonal matrix diagonal element at [160, 160] = 1.503183
# Tridiagonal matrix off-diagonal element at [161, 160] = 80.992264
# Estimated eigenvalue: -161.229937
#
# --- Iteration 162 ---
# Tridiagonal matrix diagonal element at [161, 161] = 1.145970
# Tridiagonal matrix off-diagonal element at [162, 161] = 80.843770
# Estimated eigenvalue: -161.229968
#
# --- Iteration 163 ---
# Tridiagonal matrix diagonal element at [162, 162] = -0.134188
# Tridiagonal matrix off-diagonal element at [163, 162] = 81.090140
# Estimated eigenvalue: -161.230055
#
# --- Iteration 164 ---
# Tridiagonal matrix diagonal element at [163, 163] = -0.436731
# Tridiagonal matrix off-diagonal element at [164, 163] = 79.878151
# Estimated eigenvalue: -161.230438
#
# --- Iteration 165 ---
# Tridiagonal matrix diagonal element at [164, 164] = 0.789327
# Tridiagonal matrix off-diagonal element at [165, 164] = 81.324293
# Estimated eigenvalue: -161.231234
#
# --- Iteration 166 ---
# Tridiagonal matrix diagonal element at [165, 165] = 0.392703
# Tridiagonal matrix off-diagonal element at [166, 165] = 80.031504
# Estimated eigenvalue: -161.232051
#
# --- Iteration 167 ---
# Tridiagonal matrix diagonal element at [166, 166] = 0.864728
# Tridiagonal matrix off-diagonal element at [167, 166] = 80.221739
# Estimated eigenvalue: -161.232763
#
# --- Iteration 168 ---
# Tridiagonal matrix diagonal element at [167, 167] = 2.353632
# Tridiagonal matrix off-diagonal element at [168, 167] = 80.143477
# Estimated eigenvalue: -161.233345
#
# --- Iteration 169 ---
# Tridiagonal matrix diagonal element at [168, 168] = -0.514543
# Tridiagonal matrix off-diagonal element at [169, 168] = 80.058342
# Estimated eigenvalue: -161.233809
#
# --- Iteration 170 ---
# Tridiagonal matrix diagonal element at [169, 169] = -0.488026
# Tridiagonal matrix off-diagonal element at [170, 169] = 80.994104
# Estimated eigenvalue: -161.234181
#
# --- Iteration 171 ---
# Tridiagonal matrix diagonal element at [170, 170] = 3.351016
# Tridiagonal matrix off-diagonal element at [171, 170] = 80.425369
# Estimated eigenvalue: -161.234481
#
# --- Iteration 172 ---
# Tridiagonal matrix diagonal element at [171, 171] = -0.869097
# Tridiagonal matrix off-diagonal element at [172, 171] = 80.655719
# Estimated eigenvalue: -161.234720
#
# --- Iteration 173 ---
